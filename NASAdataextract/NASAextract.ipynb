# %% [markdown]
# ## NASA dataset feature extraction
#
# In this notebook, we will perform step by step operations on extracting features from the NASA datasets.
#
# Our target is to extract useful features for SOH estimation.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import os

# %% [markdown]
# ### 1.1 DataSet Introduction
#
# When you open a matfile of the NASA dataset, eg: B0005.mat, you will see the Data structure like below:
#
# Data Structure:
# - cycle:	top level structure array containing the charge, discharge and impedance operations
# 	- type: 	operation  type, can be charge, discharge or impedance(which correspondent to the fields below)
# 	- ambient_temperature:	ambient temperature (degree C)
# 	- time: 	the date and time of the start of the cycle, in MATLAB  date vector format
# 	- data:	data structure containing the measurements
#
# - for charge the fields are:
# 	- Voltage_measured: 	Battery terminal voltage (Volts)
# 	- Current_measured:	Battery output current (Amps)
# 	- Temperature_measured: 	Battery temperature (degree C)
# 	- Current_charge:		Current measured at charger (Amps)
# 	- Voltage_charge:		Voltage measured at charger (Volts)
# 	- Time:			Time vector for the cycle (secs)
#
# - for discharge the fields are:
# 	- Voltage_measured: 	Battery terminal voltage (Volts)
# 	- Current_measured:	Battery output current (Amps)
# 	- Temperature_measured: 	Battery temperature (degree C)
# 	- Current_charge:		Current measured at load (Amps)
# 	- Voltage_charge:		Voltage measured at load (Volts)
# 	- Time:			Time vector for the cycle (secs)
# 	- Capacity:		Battery capacity (Ahr) for discharge till 2.7V
#
# - for impedance the fields are:
# 	- Sense_current:		Current in sense branch (Amps)
# 	- Battery_current:	Current in battery branch (Amps)
# 	- Current_ratio:		Ratio of the above currents
# 	- Battery_impedance:	Battery impedance (Ohms) computed from raw data
# 	- Rectified_impedance:	Calibrated and smoothed battery impedance (Ohms)
# 	- Re:			Estimated electrolyte resistance (Ohms)
# 	- Rct:			Estimated charge transfer resistance (Ohms)
#
# This is meaning that on each battery, there will be several cycles performed on it and the cycle type might be different(charge, discharge, impedance). And all of them are aggregated in this one mat file.
#
# We will inspect and perform different operations on each type of the cycle accordingly in the section below.

# %% [markdown]
# ### 2.1 charge feature extraction
#
# #### 2.1.1 CC-CV mode separation
# As for the charge fields, since the charging is composite of both CC and CV mode, we need to separate the CC mode and CV mode from this whole cycle data.
#
# According to each dataset's readme file, we know the rules of CC and CV mode charging, so we define the rules like below:
#
# - as long as the voltage is exceeding the 4.2V, then we take the index of that row into account and any rows that is on top of the row is count as CC mode.
# - any rows that is below that row is count as CV mode.
#
# However, we may do some sampling from the data to ensure the better correlation between the data and SOH. For example, just get 4.0V - 4.2V of the CC mode/just get 1.0A - 0.2A of the CV mode while we will just do the full dataset in this version.
#
# Below will be the code for doing the separation.

# %%
def separate_cc_cv(data):
    data = data.reset_index(drop=True)  # Reset the index within each group
    try:
        # Find the relative index where Voltage exceeds 4.2V
        cc_end_idx = data[data['Voltage_Measured'] >= 4.2].index[0]
    except IndexError:
        # If no index is found, assign all data to CC mode and CV mode as empty
        cc_end_idx = None
    
    if cc_end_idx is not None:
        # Separate CC and CV mode data
        cc_data = data.iloc[:cc_end_idx+1]
        cv_data = data.iloc[cc_end_idx+1:]
    else:
        return None, None
    
    cc_data = cc_data[(cc_data['Voltage_Measured'] >= 3.9) & (cc_data['Voltage_Measured'] <= 4.1)]
    cv_data = cv_data[(cv_data['Current_Measured'] >= 0.5) & (cv_data['Current_Measured'] <= 1.4)]
    return cc_data, cv_data

# %% [markdown]
# #### 2.1.2 feature calculation for cycle
# As for each charging cycle, we will use some statistical, time series, and computational physics method for describing the characteristics of the cycle data.
#
# Below are the lists of features that we used:
# - Mean
# - Standard Deviation
# - Kurtosis
# - Skewness
# - Charging Time
# - Accumulated Charge
# - Curve Slope
# - Curve Entropy
#
# For above features, we are using to describe the CC mode/CV mode current and voltage data. To be specific, for CC mode, we are calculating the voltage mean, standard deviation, kurtosis, skewness, slope and entropy because the current is constant. As for CV mode, we do the same thing for the current because the voltage is constant.

# %%
def calculate_CC_features(data):
    # Initialize a dictionary to hold the calculated features
    features = {}
    
    # Voltage features
    features['voltage mean'] = data['Voltage_Measured'].mean()
    features['voltage std'] = data['Voltage_Measured'].std()
    features['voltage kurtosis'] = stats.kurtosis(data['Voltage_Measured'])
    features['voltage skewness'] = stats.skew(data['Voltage_Measured'])
    
    # Temperature features
    features['CC_temperature mean'] = data['Temperature'].mean()
    features['CC_temperature std'] = data['Temperature'].std()
    features['CC_temperature kurtosis'] = stats.kurtosis(data['Temperature'])
    features['CC_temperature skewness'] = stats.skew(data['Temperature'])
    
    # Charging time
    t_start = data['Time'].iloc[0]
    t_end = data['Time'].iloc[-1]
    features['CC charge time'] = t_end - t_start
    
    # Accumulated charge (Q)
    I = data['Current_Measured']
    dt = data['Time'].diff().fillna(0)  # Time differences
    Q = (I * dt).sum()
    features['CC Q'] = Q
    
    # Voltage slope
    V_start = data['Voltage_Measured'].iloc[0]
    V_end = data['Voltage_Measured'].iloc[-1]
    features['voltage slope'] = (V_end - V_start) / features['CC charge time']
    
    # Voltage entropy
    voltage_counts = data['Voltage_Measured'].value_counts(normalize=True)
    features['voltage entropy'] = -np.sum(voltage_counts * np.log(voltage_counts))
    
    return features

def calculate_CV_features(data):
    # Initialize a dictionary to hold the calculated features
    features = {}
    
    # Current features
    features['current mean'] = data['Current_Measured'].mean()
    features['current std'] = data['Current_Measured'].std()
    features['current kurtosis'] = stats.kurtosis(data['Current_Measured'])
    features['current skewness'] = stats.skew(data['Current_Measured'])
    
    # Temperature features
    features['CV_temperature mean'] = data['Temperature'].mean()
    features['CV_temperature std'] = data['Temperature'].std()
    features['CV_temperature kurtosis'] = stats.kurtosis(data['Temperature'])
    features['CV_temperature skewness'] = stats.skew(data['Temperature'])
    
    # Charging time
    t_start = data['Time'].iloc[0]
    t_end = data['Time'].iloc[-1]
    features['CV charge time'] = t_end - t_start
    
    # Accumulated charge (Q)
    I = data['Current_Measured']
    dt = data['Time'].diff().fillna(0)  # Time differences
    Q = (I * dt).sum()
    features['CV Q'] = Q
    
    # Current slope
    I_start = data['Current_Measured'].iloc[0]
    I_end = data['Current_Measured'].iloc[-1]
    features['current slope'] = (I_end - I_start) / features['CV charge time']
    
    # Current entropy
    current_counts = data['Current_Measured'].value_counts(normalize=True)
    features['current entropy'] = -np.sum(current_counts * np.log(current_counts))
    
    return features

# %% [markdown]
# Below is the python script that will do the CC/CV mode separation and the feature calculation work.
#
# All the data will be saved to the path NASA/ChargeOutput
#
# Before this step, you should run the NASA/NASAdataextract/NASAmatscript/NASAchargeExtract.m in the MATLAB for generating necessary data from source data.

# %%
def process_charge_csv(file_path, cc_cv_output):
    data = pd.read_csv(file_path)
    results = []
    # Extract battery identifier from file name
    battery_id = os.path.basename(file_path).split('_')[0]
    for cycle_life, cycle_data in data.groupby('Cycle Life'):
        cc_data, cv_data = separate_cc_cv(cycle_data)
        if cc_data is None or cv_data is None:
            print(f"Skipping Cycle Life {cycle_life} in file {file_path} due to missing CC/CV separation")
            continue

        # TODO: turn the cc_data and cv_data into a dataframe and saved into a csv based on the batteries(eg: B0005)
        if not cc_data.empty:
            cc_data.to_csv(os.path.join(cc_cv_output, f'{battery_id}_Cycle_{cycle_life}_CC.csv'), index=False)
        
        if not cv_data.empty:
            cv_data.to_csv(os.path.join(cc_cv_output, f'{battery_id}_Cycle_{cycle_life}_CV.csv'), index=False)

        cc_features = {}
        cv_features = {}

        if not cc_data.empty:
            cc_features = calculate_CC_features(cc_data)

        if not cv_data.empty:
            cv_features = calculate_CV_features(cv_data)

        # Merge CC and CV features into a single dictionary
        combined_features = {**cc_features, **cv_features}
        combined_features['charge cycle life'] = cycle_life
        
        results.append(combined_features)
    
    return pd.DataFrame(results)

# 电池Batch信息

Batch1 = ['B0005','B0006','B0007','B0018']
Batch2 = ['B0025','B0026','B0027','B0028']
Batch3 = ['B0029','B0030','B0031','B0032']
Batch4 = ['B0033','B0034','B0036']
Batch5 = ['B0038','B0039','B0040']
Batch6 = ['B0041','B0042','B0043', 'B0044']
Batch7 = ['B0045','B0046','B0047','B0048']
Batch8 = ['B0049','B0050','B0051','B0052']
Batch9 = ['B0053','B0054','B0055','B0056']

# recreate the above information into a dictionary
Batch = {'Batch1': Batch1, 'Batch2': Batch2, 'Batch3': Batch3, 'Batch4': Batch4, 'Batch5': Batch5, 'Batch6': Batch6, 'Batch7': Batch7, 'Batch8': Batch8, 'Batch9': Batch9}

# 设置文件夹路径
root = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeExtract'
output_folder = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput'
cc_cv_output = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/CC_CV_Output'
files = [f for f in os.listdir(root) if f.endswith('.csv')]

all_results = []

for batch in Batch:
    for battery in Batch[batch]:
        file = [f for f in os.listdir(root) if f.endswith('.csv') and f.startswith(battery)]
        if not file:
            continue
        file_path = os.path.join(root, file[0])
        df = process_charge_csv(file_path, cc_cv_output)
        all_results.append(df)
        final_charge_df = pd.concat(all_results, ignore_index=True)
        if(not os.path.exists(os.path.join(output_folder, batch))):
            os.makedirs(os.path.join(output_folder, batch))
        final_charge_df.to_csv(os.path.join(output_folder, batch, f'{battery}_charge_features.csv'), index=False)

print('Charge Feature extraction completed.')
# Out:
# Skipping Cycle Life 80 in file /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeExtract/B0025.mat_chargeExtract.csv due to missing CC/CV separation
# Skipping Cycle Life 80 in file /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeExtract/B0026.mat_chargeExtract.csv due to missing CC/CV separation
# Skipping Cycle Life 80 in file /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeExtract/B0027.mat_chargeExtract.csv due to missing CC/CV separation
# Skipping Cycle Life 80 in file /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeExtract/B0028.mat_chargeExtract.csv due to missing CC/CV separation
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:8: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage kurtosis'] = stats.kurtosis(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:9: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage skewness'] = stats.skew(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:14: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature kurtosis'] = stats.kurtosis(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:15: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature skewness'] = stats.skew(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   features['voltage slope'] = (V_end - V_start) / features['CC charge time']
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:8: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage kurtosis'] = stats.kurtosis(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:9: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage skewness'] = stats.skew(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:14: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature kurtosis'] = stats.kurtosis(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:15: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature skewness'] = stats.skew(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   features['voltage slope'] = (V_end - V_start) / features['CC charge time']
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:8: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage kurtosis'] = stats.kurtosis(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:9: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage skewness'] = stats.skew(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:14: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature kurtosis'] = stats.kurtosis(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:15: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature skewness'] = stats.skew(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   features['voltage slope'] = (V_end - V_start) / features['CC charge time']
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:8: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage kurtosis'] = stats.kurtosis(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:9: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage skewness'] = stats.skew(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:14: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature kurtosis'] = stats.kurtosis(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:15: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature skewness'] = stats.skew(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   features['voltage slope'] = (V_end - V_start) / features['CC charge time']
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:8: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage kurtosis'] = stats.kurtosis(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:9: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage skewness'] = stats.skew(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:14: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature kurtosis'] = stats.kurtosis(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:15: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature skewness'] = stats.skew(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   features['voltage slope'] = (V_end - V_start) / features['CC charge time']
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:8: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage kurtosis'] = stats.kurtosis(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:9: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage skewness'] = stats.skew(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:14: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature kurtosis'] = stats.kurtosis(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:15: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature skewness'] = stats.skew(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   features['voltage slope'] = (V_end - V_start) / features['CC charge time']
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:8: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage kurtosis'] = stats.kurtosis(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:9: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage skewness'] = stats.skew(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:14: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature kurtosis'] = stats.kurtosis(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:15: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature skewness'] = stats.skew(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   features['voltage slope'] = (V_end - V_start) / features['CC charge time']
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:8: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage kurtosis'] = stats.kurtosis(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:9: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage skewness'] = stats.skew(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:14: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature kurtosis'] = stats.kurtosis(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:15: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature skewness'] = stats.skew(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   features['voltage slope'] = (V_end - V_start) / features['CC charge time']
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:8: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage kurtosis'] = stats.kurtosis(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:9: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage skewness'] = stats.skew(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:14: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature kurtosis'] = stats.kurtosis(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:15: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature skewness'] = stats.skew(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   features['voltage slope'] = (V_end - V_start) / features['CC charge time']
# Skipping Cycle Life 10 in file /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeExtract/B0050.mat_chargeExtract.csv due to missing CC/CV separation
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:8: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage kurtosis'] = stats.kurtosis(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:9: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage skewness'] = stats.skew(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:14: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature kurtosis'] = stats.kurtosis(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:15: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature skewness'] = stats.skew(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   features['voltage slope'] = (V_end - V_start) / features['CC charge time']
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:46: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['current kurtosis'] = stats.kurtosis(data['Current_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:47: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['current skewness'] = stats.skew(data['Current_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:52: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CV_temperature kurtosis'] = stats.kurtosis(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:53: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CV_temperature skewness'] = stats.skew(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:69: RuntimeWarning: invalid value encountered in scalar divide
#   features['current slope'] = (I_end - I_start) / features['CV charge time']
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:8: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage kurtosis'] = stats.kurtosis(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:9: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['voltage skewness'] = stats.skew(data['Voltage_Measured'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:14: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature kurtosis'] = stats.kurtosis(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:15: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features['CC_temperature skewness'] = stats.skew(data['Temperature'])
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/3026227782.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   features['voltage slope'] = (V_end - V_start) / features['CC charge time']
# Charge Feature extraction completed.

# %% [markdown]
# ### 3.1 Discharge Extraction
#
# #### 3.1.1 Discharge CC/CV & feature calculation
#
# Due to the fact that all the discharge protocols are the same over the NASA dataset, we will not separate the CC/CV mode but uniformly using CC mode. According to the Readme file of the dataset, Discharge was carried out at a constant current (CC) level of 2A until the battery voltage fell to several different constant voltage. Hence, for the Discharge features, we will still use the same metrics as charges do, that is:
# - Mean
# - Standard Deviation
# - Kurtosis
# - Skewness
# - Slope
# - Entropy
# - Charging Time
# - Accumulated Charge
#
# Before this step, you should run the NASAdischargeExtract.m script in the MATLAB to extract necessary discharge data from the raw data.

# %%
def calculate_discharge_features(data):
    # Initialize a dictionary to hold the calculated features
    features = {}
    
    # Voltage features
    features['discharge voltage mean'] = data['Voltage_Measured'].mean()
    features['discharge voltage std'] = data['Voltage_Measured'].std()
    features['discharge voltage kurtosis'] = stats.kurtosis(data['Voltage_Measured'])
    features['discharge voltage skewness'] = stats.skew(data['Voltage_Measured'])
    features['discharge voltage cov'] = features['discharge voltage std'] / features['discharge voltage mean']


    # Temperature features
    features['discharge_temperature mean'] = data['Temperature'].mean()
    features['discharge_temperature std'] = data['Temperature'].std()
    features['discharge_temperature kurtosis'] = stats.kurtosis(data['Temperature'])
    features['discharge_temperature skewness'] = stats.skew(data['Temperature'])
    features['discharge_temperature cov'] = features['discharge_temperature std'] / features['discharge_temperature mean']

    # Charging time
    t_start = data['Time'].iloc[0]
    t_end = data['Time'].iloc[-1]
    features['discharge time'] = t_end - t_start
    
    # Accumulated charge (Q)
    I = data['Current_Measured']
    dt = data['Time'].diff().fillna(0)  # Time differences
    Q = (I * dt).sum()
    features['discharge Q'] = Q
    
    # Voltage slope
    V_start = data['Voltage_Measured'].iloc[0]
    V_end = data['Voltage_Measured'].iloc[-1]
    features['discharge voltage slope'] = (V_end - V_start) / features['discharge time']
    
    # Voltage entropy
    voltage_counts = data['Voltage_Measured'].value_counts(normalize=True)
    features['discharge voltage entropy'] = stats.entropy(voltage_counts)
    features['capacity'] = data['Capacity'].iloc[0]
    return features

def process_discharge_csv(file_path):
    data = pd.read_csv(file_path)
    results = []
    
    for cycle_life, cycle_data in data.groupby('Cycle Life'):
        features = calculate_discharge_features(cycle_data)
        features['discharge cycle life'] = cycle_life
        results.append(features)
    
    return pd.DataFrame(results)

# 设置文件夹路径
root = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeExtract'
output_folder = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput'
files = [f for f in os.listdir(root) if f.endswith('.csv')]

for batch in Batch:
    for battery in Batch[batch]:
        file = [f for f in os.listdir(root) if f.endswith('.csv') and f.startswith(battery)]
        if not file:
            continue
        file_path = os.path.join(root, file[0])
        df = process_discharge_csv(file_path)
        batch_output_folder = os.path.join(output_folder, batch)
        if not os.path.exists(batch_output_folder):
            os.makedirs(batch_output_folder)
        df.to_csv(os.path.join(batch_output_folder, f'{battery}_discharge_features.csv'), index=False)

print('Discharge Feature extraction completed.')
# Out:
# Discharge Feature extraction completed.

# %% [markdown]
# ### 4.1 Impedance Extraction
#
# #### 4.1.1 Complex number processing
#
# For the impedance cycles, there are several columns that is containing the complex numbers. As we all know, the complex number has real number part and imag number part. By using the function in MATLAB script, we have extract the real number part and the imag number part.
#
# Since the current ratio, sense current and battery current makes no impact to the capacity that we are going to measure, we just simply not using them.
#
# We make the separation operation for complex number for battery impedance and rectified impedance. From physics law, we know that the impedance is highly related to the Li-battery's state of health. So we extract mean and max value of those two columns to be the feature.
#
# Since the calculation and the processing of the complex number is not that hard, we are not writing a single function in python file for processing them. All the processing steps are done within the mat script under NASAdataextract/NASAmatscript/NASAimpedanceExtract.m

# %% [markdown]
# ### 5.1 Merge Features
#
# #### 5.1.1 cycle number matching
#
# Remember we have a column called cycle number for charge, discharge and impedance. Now, it is the time for using it !
#
# The cycle order in the NASA dataset is not that periodic. As for the charge and discharge, it is periodic as charge - discharge - charge - discharge. However, for the impedance, it is kind of random.
#
# We inspect all the features generated for impedance, charge and discharge and found the discharge data is the bottleneck, all the charge cycle and impedance cycle will be dependent on the discharge cycle
#
# So we set the rules like below:
# - for charge cycle, its cycle life should be +2 to the discharge cycle
# - for impedance cycle, its cycle life should be +1 to the discharge cycle

# %% [markdown]
# And we need to first preprocess the charge/discharge/impedance cycle to drop the nan rows.

# %%
def preprocess_data(file_path):
    # Load data
    data = pd.read_csv(file_path)
    
    # Drop rows containing NaN, blank, or zero values
    data = data.replace('', pd.NA).dropna()
    data = data[(data != 0).all(axis=1)]
    
    return data

def preprocess_folder(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for batch in os.listdir(input_folder):
        batch_folder = os.path.join(input_folder, batch)
        if os.path.isdir(batch_folder):
            output_batch_folder = os.path.join(output_folder, batch)
            if not os.path.exists(output_batch_folder):
                os.makedirs(output_batch_folder)
            
            for file in os.listdir(batch_folder):
                if file.endswith('.csv'):
                    file_path = os.path.join(batch_folder, file)
                    cleaned_data = preprocess_data(file_path)
                    output_file_path = os.path.join(output_batch_folder, file)
                    cleaned_data.to_csv(output_file_path, index=False)
                    print(f'Processed and saved: {output_file_path}')

# Define input and output folders
charge_input_folder = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput'
charge_output_folder = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned'

discharge_input_folder = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput'
discharge_output_folder = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned'

impedance_input_folder = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput'
impedance_output_folder = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned'

# Preprocess data
print('Processing charge data...')
preprocess_folder(charge_input_folder, charge_output_folder)

print('Processing discharge data...')
preprocess_folder(discharge_input_folder, discharge_output_folder)

print('Processing impedance data...')
preprocess_folder(impedance_input_folder, impedance_output_folder)

print('Data preprocessing completed.')
# Out:
# Processing charge data...
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch8/B0052_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch8/B0049_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch8/B0050_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch8/B0051_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch6/B0044_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch6/B0041_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch6/B0042_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch6/B0043_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch1/B0006_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch1/B0007_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch1/B0005_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch1/B0018_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch7/B0045_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch7/B0047_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch7/B0046_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch7/B0048_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch9/B0056_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch9/B0055_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch9/B0054_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch9/B0053_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch2/B0028_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch2/B0027_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch2/B0026_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch2/B0025_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch5/B0040_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch5/B0039_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch5/B0038_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch4/B0033_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch4/B0034_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch4/B0036_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch3/B0029_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch3/B0030_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch3/B0031_charge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned/Batch3/B0032_charge_features.csv
# Processing discharge data...
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch8/B0049_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch8/B0052_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch8/B0051_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch8/B0050_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch6/B0041_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch6/B0042_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch6/B0043_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch6/B0044_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch1/B0005_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch1/B0006_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch1/B0007_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch1/B0018_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch7/B0046_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch7/B0045_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch7/B0048_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch7/B0047_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch9/B0055_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch9/B0056_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch9/B0054_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch9/B0053_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch2/B0027_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch2/B0025_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch2/B0028_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch2/B0026_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch5/B0039_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch5/B0038_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch5/B0040_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch4/B0034_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch4/B0033_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch4/B0036_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch3/B0030_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch3/B0031_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch3/B0032_discharge_features.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned/Batch3/B0029_discharge_features.csv
# Processing impedance data...
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch8/B0049.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch8/B0050.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch8/B0051.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch6/B0041.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch6/B0044.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch6/B0042.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch6/B0043.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch1/B0018.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch1/B0006.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch1/B0007.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch1/B0005.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch7/B0045.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch7/B0048.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch7/B0046.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch7/B0047.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch9/B0053.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch9/B0056.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch9/B0054.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch9/B0055.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch2/B0027.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch2/B0026.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch2/B0028.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch2/B0025.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch5/B0039.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch5/B0038.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch5/B0040.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch4/B0034.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch4/B0036.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch4/B0033.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch3/B0031.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch3/B0030.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch3/B0032.mat_ImpedanceExtract.csv
# Processed and saved: /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned/Batch3/B0029.mat_ImpedanceExtract.csv
# Data preprocessing completed.

# %% [markdown]
# And then we will perform our merge process.

# %%
# Set the folder paths
charge_folder = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ChargeOutput_Cleaned'
discharge_folder = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/DischargeOutput_Cleaned'
impedance_folder = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/ImpedanceOutput_Cleaned'
output_folder = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput'

# Create the output folder if it does not exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Battery batch information
Batch = {
    'Batch1': ['B0005', 'B0006', 'B0007', 'B0018'],
    'Batch2': ['B0025', 'B0026', 'B0027', 'B0028'],
    'Batch3': ['B0029', 'B0030', 'B0031', 'B0032'],
    'Batch4': ['B0033', 'B0034', 'B0036'],
    'Batch5': ['B0038', 'B0039', 'B0040'],
    'Batch6': ['B0041', 'B0042', 'B0043', 'B0044'],
    'Batch7': ['B0045', 'B0046', 'B0047', 'B0048'],
    'Batch8': ['B0049', 'B0050', 'B0051'],
    'Batch9': ['B0053', 'B0054', 'B0055', 'B0056']
}

def find_next_cycle(df, cycle_life_col, target_cycle_life):
    df = df[df[cycle_life_col] >= target_cycle_life]
    if not df.empty:
        return df.iloc[0]
    return None

for batch_name, batteries in Batch.items():
    batch_output_folder = os.path.join(output_folder, batch_name)
    if not os.path.exists(batch_output_folder):
        os.makedirs(batch_output_folder)
    
    discharge_batch_folder = os.path.join(discharge_folder, batch_name)
    charge_batch_folder = os.path.join(charge_folder, batch_name)
    impedance_batch_folder = os.path.join(impedance_folder, batch_name)
    
    for battery in batteries:
        discharge_file = f'{battery}_discharge_features.csv'
        charge_file = f'{battery}_charge_features.csv'
        impedance_file = f'{battery}.mat_ImpedanceExtract.csv'
        
        if os.path.exists(os.path.join(discharge_batch_folder, discharge_file)):
            discharge_data = pd.read_csv(os.path.join(discharge_batch_folder, discharge_file))
            charge_data = pd.read_csv(os.path.join(charge_batch_folder, charge_file)) if os.path.exists(os.path.join(charge_batch_folder, charge_file)) else pd.DataFrame()
            impedance_data = pd.read_csv(os.path.join(impedance_batch_folder, impedance_file)) if os.path.exists(os.path.join(impedance_batch_folder, impedance_file)) else pd.DataFrame()
            
            merged_data = []

            for _, impedance_row in impedance_data.iterrows():
                impedance_cycle_life = impedance_row['Impedance Cycle Life']
                # Find corresponding discharge cycle
                target_discharge_cycle_life = impedance_cycle_life - 1
                discharge_row = find_next_cycle(discharge_data, 'discharge cycle life', target_discharge_cycle_life)
                
                # Find corresponding charge cycle
                target_charge_cycle_life = impedance_cycle_life + 1
                charge_row = find_next_cycle(charge_data, 'charge cycle life', target_charge_cycle_life)
                
                if discharge_row is not None and charge_row is not None:
                    combined_row = {**discharge_row, **charge_row, **impedance_row}
                    merged_data.append(combined_row)
            
            if merged_data:
                merged_df = pd.DataFrame(merged_data)
                output_csv = os.path.join(batch_output_folder, f'{battery}_Merged_discharge+charge+impedance.csv')
                merged_df.to_csv(output_csv, index=False)
                print(f'Merged data saved to {output_csv}')
            else:
                print(f'No merged data for battery {battery}')
        else:
            print(f'Discharge file not found for battery {battery}')

print('Data merging completed.')
# Out:
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch1/B0005_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch1/B0006_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch1/B0007_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch1/B0018_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch2/B0025_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch2/B0026_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch2/B0027_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch2/B0028_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch3/B0029_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch3/B0030_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch3/B0031_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch3/B0032_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch4/B0033_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch4/B0034_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch4/B0036_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch5/B0038_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch5/B0039_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch5/B0040_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch6/B0041_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch6/B0042_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch6/B0043_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch6/B0044_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch7/B0045_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch7/B0046_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch7/B0047_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch7/B0048_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch8/B0049_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch8/B0050_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch8/B0051_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch9/B0053_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch9/B0054_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch9/B0055_Merged_discharge+charge+impedance.csv
# Merged data saved to /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch9/B0056_Merged_discharge+charge+impedance.csv
# Data merging completed.

# %% [markdown]
# ### 6.1 Plot the Correlation Matrix
#
# #### 6.1.1 Problematic rows
#
# During the process of inspecting the rows of the csv that we merged, we found there are few problems:
#
# - some complex number combinations in B0050（Batch8）of Re and Rct unprocessed which can't be input into the neural network
# - some rows that are blank or have Nan value cuz of the merging process
# - elminate duplicate rows(you can refer to the discharge cycle life and charge cycle life for doing this)
# - eliminate some unnecessary columns eg: charge cycle life / discharge cycle life.

# %%
# Function to handle complex number combinations
def process_complex_numbers(df, columns):
    for column in columns:
        if column in df.columns:
            df[column] = df[column].apply(lambda x: np.real(complex(x)) if isinstance(x, str) and 'j' in x else x)
    return df

# Set the folder paths
output_folder = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput'

# Columns to remove
columns_to_remove = ['charge cycle life', 'discharge cycle life', 'Impedance Cycle Life']

# Columns with potential complex numbers
complex_columns = ['Re', 'Rct']

for batch_name in os.listdir(output_folder):
    batch_folder = os.path.join(output_folder, batch_name)
    if os.path.isdir(batch_folder):
        for file_name in os.listdir(batch_folder):
            file_path = os.path.join(batch_folder, file_name)
            if file_name.endswith('_Merged_discharge+charge+impedance.csv'):
                # Read the CSV file
                df = pd.read_csv(file_path)
                
                # Process complex numbers
                df = process_complex_numbers(df, complex_columns)
                
                # Remove rows with NaN values
                df = df.dropna()
                
                # Eliminate duplicate rows
                df = df.drop_duplicates(subset=['discharge cycle life', 'charge cycle life'])
                
                # Remove unnecessary columns
                df = df.drop(columns=columns_to_remove, errors='ignore')
                
                # Save the cleaned DataFrame back to CSV
                df.to_csv(file_path, index=False)
                print(f'Processed and cleaned {file_path}')

print('Data cleaning completed.')
# Out:
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch8/B0051_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch8/B0050_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch8/B0049_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch6/B0042_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch6/B0043_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch6/B0041_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch6/B0044_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch1/B0005_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch1/B0007_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch1/B0006_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch1/B0018_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch7/B0047_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch7/B0046_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch7/B0045_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch7/B0048_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch9/B0056_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch9/B0054_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch9/B0055_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch9/B0053_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch2/B0026_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch2/B0027_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch2/B0025_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch2/B0028_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch5/B0039_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch5/B0038_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch5/B0040_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch4/B0033_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch4/B0036_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch4/B0034_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch3/B0032_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch3/B0030_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch3/B0031_Merged_discharge+charge+impedance.csv
# Processed and cleaned /Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput/Batch3/B0029_Merged_discharge+charge+impedance.csv
# Data cleaning completed.

# %% [markdown]
# ### 6.1.2 Pearson Correlation Plot
#
# Since we have many features now, we need to plot the graph of the pearson correlation to see how it interacts with the target value of capacity for better feature engineering.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Battery batch information
Batch1 = ['B0005', 'B0006', 'B0007', 'B0018']
Batch = {'Batch1': Batch1}

# Set the output folder path
output_folder = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput'

batch1_data = []

# Load features from Batch1
for batch in Batch:
    batch_folder = os.path.join(output_folder, batch)
    if os.path.exists(batch_folder):
        files = [f for f in os.listdir(batch_folder) if f.endswith('_Merged_discharge+charge+impedance.csv')]
        for file in files:
            file_path = os.path.join(batch_folder, file)
            data = pd.read_csv(file_path)
            batch1_data.append(data)

# Combine data for Batch1 into one DataFrame
batch1_combined_data = pd.concat(batch1_data, ignore_index=True)

# Compute the Pearson correlation matrix for Batch1
batch1_correlation_matrix = batch1_combined_data.corr()

# Display the correlation matrix for Batch1
print("Pearson Correlation Matrix for Batch1:")
print(batch1_correlation_matrix)

# Plotting the Pearson correlation matrix for Batch1
plt.figure(figsize=(12, 10))
sns.heatmap(batch1_correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Pearson Correlation Matrix for Batch1')
plt.show()

# Plotting the Pearson correlation coefficients for 'capacity' in Batch1
if 'capacity' in batch1_combined_data.columns:
    batch1_pearson_corr = batch1_correlation_matrix['capacity'].drop('capacity')

    plt.figure(figsize=(10, 8))
    sns.barplot(x=batch1_pearson_corr.values, y=batch1_pearson_corr.index, palette="viridis")
    plt.title('Pearson Correlation with Capacity for Batch1')
    plt.xlabel('Pearson Correlation Coefficient')
    plt.ylabel('Features')
    plt.grid(True)  # Add grid lines for better readability
    plt.tight_layout()  # Adjust the layout to make room for the labels
    plt.show()
else:
    print("Column 'capacity' not found in the data.")
# Out:
# Pearson Correlation Matrix for Batch1:
#                                 discharge voltage mean  discharge voltage std  \
# discharge voltage mean                        1.000000              -0.211705
# discharge voltage std                        -0.211705               1.000000
# discharge voltage kurtosis                    0.521375               0.471834
# discharge voltage skewness                   -0.504862              -0.611019
# discharge voltage cov                        -0.388829               0.982694
# discharge_temperature mean                   -0.635357               0.013189
# discharge_temperature std                    -0.830695               0.336021
# discharge_temperature kurtosis                0.876038               0.016710
# discharge_temperature skewness                0.180471               0.728703
# discharge_temperature cov                    -0.806751               0.421470
# discharge time                                0.767534              -0.317909
# discharge Q                                  -0.869883               0.123006
# discharge voltage slope                      -0.632370              -0.153330
# discharge voltage entropy                    -0.071235              -0.131982
# capacity                                      0.878003              -0.159821
# voltage mean                                 -0.719094               0.273741
# voltage std                                   0.604361              -0.259815
# voltage kurtosis                             -0.438302               0.223248
# voltage skewness                              0.722202              -0.278256
# CC_temperature mean                          -0.433509               0.154157
# CC_temperature std                            0.590420              -0.210661
# CC_temperature kurtosis                       0.125660              -0.044928
# CC_temperature skewness                       0.245141              -0.090219
# CC charge time                                0.740868              -0.306509
# CC Q                                          0.740929              -0.306543
# voltage slope                                -0.702621               0.296364
# voltage entropy                               0.139608              -0.141759
# current mean                                  0.193293              -0.012172
# current std                                  -0.569118               0.221586
# current kurtosis                              0.300143              -0.197277
# current skewness                             -0.270620               0.040665
# CV_temperature mean                          -0.508578               0.207070
# CV_temperature std                            0.187944              -0.144791
# CV_temperature kurtosis                      -0.610863               0.275846
# CV_temperature skewness                       0.735039              -0.316297
# CV charge time                               -0.742086               0.295602
# CV Q                                         -0.743308               0.299750
# current slope                                -0.735521               0.287658
# current entropy                              -0.497981               0.136561
# Battery_impedance_real_mean                  -0.558225              -0.117795
# Battery_impedance_real_max                   -0.506882              -0.171215
# Battery_impedance_imag_mean                   0.394167              -0.089841
# Battery_impedance_imag_max                    0.313014              -0.050584
# Rectified_impedance_real_mean                -0.896839               0.046465
# Rectified_impedance_real_max                 -0.908144               0.058153
# Rectified_impedance_imag_mean                 0.820968              -0.061461
# Rectified_impedance_imag_max                 -0.627387               0.017982
# Re                                           -0.875678               0.059444
# Rct                                          -0.900418               0.067106
#
#                                 discharge voltage kurtosis  \
# discharge voltage mean                            0.521375
# discharge voltage std                             0.471834
# discharge voltage kurtosis                        1.000000
# discharge voltage skewness                       -0.964172
# discharge voltage cov                             0.344858
# discharge_temperature mean                       -0.420463
# discharge_temperature std                        -0.407765
# discharge_temperature kurtosis                    0.664584
# discharge_temperature skewness                    0.367310
# discharge_temperature cov                        -0.357802
# discharge time                                    0.435594
# discharge Q                                      -0.591856
# discharge voltage slope                          -0.869542
# discharge voltage entropy                        -0.232910
# capacity                                          0.567820
# voltage mean                                     -0.413276
# voltage std                                       0.283988
# voltage kurtosis                                 -0.146807
# voltage skewness                                  0.410681
# CC_temperature mean                              -0.269208
# CC_temperature std                                0.366288
# CC_temperature kurtosis                           0.066295
# CC_temperature skewness                           0.129412
# CC charge time                                    0.386920
# CC Q                                              0.386986
# voltage slope                                    -0.353609
# voltage entropy                                  -0.067713
# current mean                                      0.227231
# current std                                      -0.364371
# current kurtosis                                  0.055837
# current skewness                                 -0.264453
# CV_temperature mean                              -0.284824
# CV_temperature std                               -0.030217
# CV_temperature kurtosis                          -0.272720
# CV_temperature skewness                           0.377286
# CV charge time                                   -0.418177
# CV Q                                             -0.410765
# current slope                                    -0.424723
# current entropy                                  -0.377614
# Battery_impedance_real_mean                      -0.639267
# Battery_impedance_real_max                       -0.299114
# Battery_impedance_imag_mean                       0.272118
# Battery_impedance_imag_max                        0.271940
# Rectified_impedance_real_mean                    -0.595894
# Rectified_impedance_real_max                     -0.589658
# Rectified_impedance_imag_mean                     0.490285
# Rectified_impedance_imag_max                     -0.248125
# Re                                               -0.559583
# Rct                                              -0.576679
#
#                                 discharge voltage skewness  \
# discharge voltage mean                           -0.504862
# discharge voltage std                            -0.611019
# discharge voltage kurtosis                       -0.964172
# discharge voltage skewness                        1.000000
# discharge voltage cov                            -0.479666
# discharge_temperature mean                        0.431440
# discharge_temperature std                         0.376157
# discharge_temperature kurtosis                   -0.683690
# discharge_temperature skewness                   -0.514708
# discharge_temperature cov                         0.313232
# discharge time                                   -0.389647
# discharge Q                                       0.578569
# discharge voltage slope                           0.796155
# discharge voltage entropy                         0.164567
# capacity                                         -0.550329
# voltage mean                                      0.365353
# voltage std                                      -0.244789
# voltage kurtosis                                  0.112406
# voltage skewness                                 -0.362489
# CC_temperature mean                               0.221819
# CC_temperature std                               -0.303081
# CC_temperature kurtosis                          -0.098284
# CC_temperature skewness                          -0.135147
# CC charge time                                   -0.340131
# CC Q                                             -0.340177
# voltage slope                                     0.305634
# voltage entropy                                   0.075572
# current mean                                     -0.215062
# current std                                       0.321468
# current kurtosis                                 -0.033335
# current skewness                                  0.249842
# CV_temperature mean                               0.249756
# CV_temperature std                                0.040855
# CV_temperature kurtosis                           0.229806
# CV_temperature skewness                          -0.332827
# CV charge time                                    0.372592
# CV Q                                              0.364974
# current slope                                     0.380570
# current entropy                                   0.344299
# Battery_impedance_real_mean                       0.620210
# Battery_impedance_real_max                        0.372670
# Battery_impedance_imag_mean                      -0.218794
# Battery_impedance_imag_max                       -0.218884
# Rectified_impedance_real_mean                     0.562169
# Rectified_impedance_real_max                      0.555862
# Rectified_impedance_imag_mean                    -0.464665
# Rectified_impedance_imag_max                      0.260602
# Re                                                0.525705
# Rct                                               0.540012
#
#                                 discharge voltage cov  \
# discharge voltage mean                      -0.388829
# discharge voltage std                        0.982694
# discharge voltage kurtosis                   0.344858
# discharge voltage skewness                  -0.479666
# discharge voltage cov                        1.000000
# discharge_temperature mean                   0.131094
# discharge_temperature std                    0.472924
# discharge_temperature kurtosis              -0.149455
# discharge_temperature skewness               0.652234
# discharge_temperature cov                    0.549250
# discharge time                              -0.444911
# discharge Q                                  0.280250
# discharge voltage slope                     -0.025139
# discharge voltage entropy                   -0.111242
# capacity                                    -0.316519
# voltage mean                                 0.394365
# voltage std                                 -0.360358
# voltage kurtosis                             0.295095
# voltage skewness                            -0.399267
# CC_temperature mean                          0.225944
# CC_temperature std                          -0.309647
# CC_temperature kurtosis                     -0.067308
# CC_temperature skewness                     -0.133050
# CC charge time                              -0.429112
# CC Q                                        -0.429154
# voltage slope                                0.412982
# voltage entropy                             -0.160369
# current mean                                -0.047561
# current std                                  0.315480
# current kurtosis                            -0.243053
# current skewness                             0.089054
# CV_temperature mean                          0.289688
# CV_temperature std                          -0.172542
# CV_temperature kurtosis                      0.376344
# CV_temperature skewness                     -0.436917
# CV charge time                               0.418822
# CV Q                                         0.423043
# current slope                                0.409979
# current entropy                              0.222829
# Battery_impedance_real_mean                 -0.005305
# Battery_impedance_real_max                  -0.064888
# Battery_impedance_imag_mean                 -0.158859
# Battery_impedance_imag_max                  -0.106644
# Rectified_impedance_real_mean                0.214706
# Rectified_impedance_real_max                 0.227888
# Rectified_impedance_imag_mean               -0.214692
# Rectified_impedance_imag_max                 0.136804
# Re                                           0.223007
# Rct                                          0.234907
#
#                                 discharge_temperature mean  \
# discharge voltage mean                           -0.635357
# discharge voltage std                             0.013189
# discharge voltage kurtosis                       -0.420463
# discharge voltage skewness                        0.431440
# discharge voltage cov                             0.131094
# discharge_temperature mean                        1.000000
# discharge_temperature std                         0.770547
# discharge_temperature kurtosis                   -0.515280
# discharge_temperature skewness                   -0.139968
# discharge_temperature cov                         0.601759
# discharge time                                   -0.634049
# discharge Q                                       0.708724
# discharge voltage slope                           0.516039
# discharge voltage entropy                         0.204493
# capacity                                         -0.705845
# voltage mean                                      0.706179
# voltage std                                      -0.548321
# voltage kurtosis                                  0.365835
# voltage skewness                                 -0.705643
# CC_temperature mean                               0.727264
# CC_temperature std                               -0.586040
# CC_temperature kurtosis                          -0.151504
# CC_temperature skewness                          -0.254541
# CC charge time                                   -0.747061
# CC Q                                             -0.747168
# voltage slope                                     0.685277
# voltage entropy                                  -0.126188
# current mean                                     -0.253854
# current std                                       0.514596
# current kurtosis                                 -0.178967
# current skewness                                  0.297973
# CV_temperature mean                               0.813400
# CV_temperature std                               -0.142473
# CV_temperature kurtosis                           0.605630
# CV_temperature skewness                          -0.702734
# CV charge time                                    0.752774
# CV Q                                              0.745653
# current slope                                     0.745698
# current entropy                                   0.509151
# Battery_impedance_real_mean                       0.690032
# Battery_impedance_real_max                        0.421238
# Battery_impedance_imag_mean                      -0.257984
# Battery_impedance_imag_max                       -0.210415
# Rectified_impedance_real_mean                     0.456457
# Rectified_impedance_real_max                      0.476166
# Rectified_impedance_imag_mean                    -0.349165
# Rectified_impedance_imag_max                      0.308045
# Re                                                0.442607
# Rct                                               0.457403
#
#                                 discharge_temperature std  \
# discharge voltage mean                          -0.830695
# discharge voltage std                            0.336021
# discharge voltage kurtosis                      -0.407765
# discharge voltage skewness                       0.376157
# discharge voltage cov                            0.472924
# discharge_temperature mean                       0.770547
# discharge_temperature std                        1.000000
# discharge_temperature kurtosis                  -0.696463
# discharge_temperature skewness                   0.083583
# discharge_temperature cov                        0.972500
# discharge time                                  -0.915701
# discharge Q                                      0.914897
# discharge voltage slope                          0.585191
# discharge voltage entropy                        0.097107
# capacity                                        -0.922247
# voltage mean                                     0.907474
# voltage std                                     -0.758514
# voltage kurtosis                                 0.540788
# voltage skewness                                -0.911420
# CC_temperature mean                              0.530062
# CC_temperature std                              -0.712840
# CC_temperature kurtosis                         -0.210940
# CC_temperature skewness                         -0.340267
# CC charge time                                  -0.937392
# CC Q                                            -0.937471
# voltage slope                                    0.885263
# voltage entropy                                 -0.174276
# current mean                                    -0.255260
# current std                                      0.708411
# current kurtosis                                -0.360919
# current skewness                                 0.359114
# CV_temperature mean                              0.646075
# CV_temperature std                              -0.234574
# CV_temperature kurtosis                          0.756650
# CV_temperature skewness                         -0.926747
# CV charge time                                   0.943231
# CV Q                                             0.943156
# current slope                                    0.936029
# current entropy                                  0.631444
# Battery_impedance_real_mean                      0.744647
# Battery_impedance_real_max                       0.295355
# Battery_impedance_imag_mean                     -0.366347
# Battery_impedance_imag_max                      -0.330683
# Rectified_impedance_real_mean                    0.605559
# Rectified_impedance_real_max                     0.634476
# Rectified_impedance_imag_mean                   -0.558850
# Rectified_impedance_imag_max                     0.268981
# Re                                               0.556233
# Rct                                              0.622936
#
#                                 discharge_temperature kurtosis  \
# discharge voltage mean                                0.876038
# discharge voltage std                                 0.016710
# discharge voltage kurtosis                            0.664584
# discharge voltage skewness                           -0.683690
# discharge voltage cov                                -0.149455
# discharge_temperature mean                           -0.515280
# discharge_temperature std                            -0.696463
# discharge_temperature kurtosis                        1.000000
# discharge_temperature skewness                        0.180709
# discharge_temperature cov                            -0.684665
# discharge time                                        0.684603
# discharge Q                                          -0.790329
# discharge voltage slope                              -0.677363
# discharge voltage entropy                             0.004126
# capacity                                              0.786629
# voltage mean                                         -0.603006
# voltage std                                           0.475384
# voltage kurtosis                                     -0.302790
# voltage skewness                                      0.603307
# CC_temperature mean                                  -0.353532
# CC_temperature std                                    0.464429
# CC_temperature kurtosis                               0.182922
# CC_temperature skewness                               0.241443
# CC charge time                                        0.607765
# CC Q                                                  0.607809
# voltage slope                                        -0.560797
# voltage entropy                                       0.043348
# current mean                                          0.226361
# current std                                          -0.494168
# current kurtosis                                      0.185874
# current skewness                                     -0.288167
# CV_temperature mean                                  -0.439230
# CV_temperature std                                    0.086552
# CV_temperature kurtosis                              -0.472925
# CV_temperature skewness                               0.604397
# CV charge time                                       -0.629478
# CV Q                                                 -0.625835
# current slope                                        -0.631331
# current entropy                                      -0.465883
# Battery_impedance_real_mean                          -0.568421
# Battery_impedance_real_max                           -0.524636
# Battery_impedance_imag_mean                           0.341230
# Battery_impedance_imag_max                            0.280019
# Rectified_impedance_real_mean                        -0.843812
# Rectified_impedance_real_max                         -0.828044
# Rectified_impedance_imag_mean                         0.677197
# Rectified_impedance_imag_max                         -0.550745
# Re                                                   -0.832078
# Rct                                                  -0.815614
#
#                                 discharge_temperature skewness  \
# discharge voltage mean                                0.180471
# discharge voltage std                                 0.728703
# discharge voltage kurtosis                            0.367310
# discharge voltage skewness                           -0.514708
# discharge voltage cov                                 0.652234
# discharge_temperature mean                           -0.139968
# discharge_temperature std                             0.083583
# discharge_temperature kurtosis                        0.180709
# discharge_temperature skewness                        1.000000
# discharge_temperature cov                             0.166960
# discharge time                                       -0.126143
# discharge Q                                          -0.155123
# discharge voltage slope                              -0.170245
# discharge voltage entropy                             0.106127
# capacity                                              0.132046
# voltage mean                                          0.113742
# voltage std                                           0.024528
# voltage kurtosis                                     -0.150339
# voltage skewness                                     -0.105866
# CC_temperature mean                                   0.108206
# CC_temperature std                                   -0.080468
# CC_temperature kurtosis                              -0.102237
# CC_temperature skewness                              -0.049480
# CC charge time                                       -0.070257
# CC Q                                                 -0.070326
# voltage slope                                         0.014788
# voltage entropy                                       0.218778
# current mean                                         -0.258259
# current std                                           0.192986
# current kurtosis                                      0.163074
# current skewness                                      0.251862
# CV_temperature mean                                   0.151418
# CV_temperature std                                    0.222361
# CV_temperature kurtosis                              -0.040089
# CV_temperature skewness                              -0.076556
# CV charge time                                        0.139021
# CV Q                                                  0.120776
# current slope                                         0.160865
# current entropy                                       0.235274
# Battery_impedance_real_mean                          -0.065447
# Battery_impedance_real_max                           -0.466167
# Battery_impedance_imag_mean                          -0.184349
# Battery_impedance_imag_max                           -0.195592
# Rectified_impedance_real_mean                        -0.293083
# Rectified_impedance_real_max                         -0.313282
# Rectified_impedance_imag_mean                         0.389991
# Rectified_impedance_imag_max                         -0.297552
# Re                                                   -0.267521
# Rct                                                  -0.306823
#
#                                 discharge_temperature cov  ...  \
# discharge voltage mean                          -0.806751  ...
# discharge voltage std                            0.421470  ...
# discharge voltage kurtosis                      -0.357802  ...
# discharge voltage skewness                       0.313232  ...
# discharge voltage cov                            0.549250  ...
# discharge_temperature mean                       0.601759  ...
# discharge_temperature std                        0.972500  ...
# discharge_temperature kurtosis                  -0.684665  ...
# discharge_temperature skewness                   0.166960  ...
# discharge_temperature cov                        1.000000  ...
# discharge time                                  -0.918893  ...
# discharge Q                                      0.887793  ...
# discharge voltage slope                          0.546530  ...
# discharge voltage entropy                        0.048416  ...
# capacity                                        -0.898108  ...
# voltage mean                                     0.881028  ...
# voltage std                                     -0.747111  ...
# voltage kurtosis                                 0.537294  ...
# voltage skewness                                -0.885892  ...
# CC_temperature mean                              0.403522  ...
# CC_temperature std                              -0.680523  ...
# CC_temperature kurtosis                         -0.212729  ...
# CC_temperature skewness                         -0.334681  ...
# CC charge time                                  -0.901521  ...
# CC Q                                            -0.901583  ...
# voltage slope                                    0.857154  ...
# voltage entropy                                 -0.162820  ...
# current mean                                    -0.238096  ...
# current std                                      0.704030  ...
# current kurtosis                                -0.377636  ...
# current skewness                                 0.350421  ...
# CV_temperature mean                              0.518243  ...
# CV_temperature std                              -0.231113  ...
# CV_temperature kurtosis                          0.723970  ...
# CV_temperature skewness                         -0.903933  ...
# CV charge time                                   0.909499  ...
# CV Q                                             0.911144  ...
# current slope                                    0.903931  ...
# current entropy                                  0.612907  ...
# Battery_impedance_real_mean                      0.683285  ...
# Battery_impedance_real_max                       0.208535  ...
# Battery_impedance_imag_mean                     -0.367338  ...
# Battery_impedance_imag_max                      -0.340518  ...
# Rectified_impedance_real_mean                    0.586728  ...
# Rectified_impedance_real_max                     0.615476  ...
# Rectified_impedance_imag_mean                   -0.566562  ...
# Rectified_impedance_imag_max                     0.216654  ...
# Re                                               0.530014  ...
# Rct                                              0.607872  ...
#
#                                 Battery_impedance_real_mean  \
# discharge voltage mean                            -0.558225
# discharge voltage std                             -0.117795
# discharge voltage kurtosis                        -0.639267
# discharge voltage skewness                         0.620210
# discharge voltage cov                             -0.005305
# discharge_temperature mean                         0.690032
# discharge_temperature std                          0.744647
# discharge_temperature kurtosis                    -0.568421
# discharge_temperature skewness                    -0.065447
# discharge_temperature cov                          0.683285
# discharge time                                    -0.785598
# discharge Q                                        0.791398
# discharge voltage slope                            0.648374
# discharge voltage entropy                          0.405120
# capacity                                          -0.779496
# voltage mean                                       0.835390
# voltage std                                       -0.651553
# voltage kurtosis                                   0.421996
# voltage skewness                                  -0.833343
# CC_temperature mean                                0.521988
# CC_temperature std                                -0.667225
# CC_temperature kurtosis                           -0.190717
# CC_temperature skewness                           -0.345321
# CC charge time                                    -0.804946
# CC Q                                              -0.805009
# voltage slope                                      0.764331
# voltage entropy                                    0.012650
# current mean                                      -0.360617
# current std                                        0.648420
# current kurtosis                                  -0.176710
# current skewness                                   0.434759
# CV_temperature mean                                0.575598
# CV_temperature std                                -0.056427
# CV_temperature kurtosis                            0.633008
# CV_temperature skewness                           -0.770441
# CV charge time                                     0.837138
# CV Q                                               0.829775
# current slope                                      0.837006
# current entropy                                    0.682348
# Battery_impedance_real_mean                        1.000000
# Battery_impedance_real_max                         0.113240
# Battery_impedance_imag_mean                       -0.556029
# Battery_impedance_imag_max                        -0.582886
# Rectified_impedance_real_mean                      0.508083
# Rectified_impedance_real_max                       0.522254
# Rectified_impedance_imag_mean                     -0.422447
# Rectified_impedance_imag_max                       0.040504
# Re                                                 0.442626
# Rct                                                0.512135
#
#                                 Battery_impedance_real_max  \
# discharge voltage mean                           -0.506882
# discharge voltage std                            -0.171215
# discharge voltage kurtosis                       -0.299114
# discharge voltage skewness                        0.372670
# discharge voltage cov                            -0.064888
# discharge_temperature mean                        0.421238
# discharge_temperature std                         0.295355
# discharge_temperature kurtosis                   -0.524636
# discharge_temperature skewness                   -0.466167
# discharge_temperature cov                         0.208535
# discharge time                                   -0.137375
# discharge Q                                       0.330953
# discharge voltage slope                           0.305512
# discharge voltage entropy                        -0.320805
# capacity                                         -0.326872
# voltage mean                                      0.170103
# voltage std                                      -0.286061
# voltage kurtosis                                  0.342381
# voltage skewness                                 -0.181769
# CC_temperature mean                               0.083357
# CC_temperature std                               -0.072861
# CC_temperature kurtosis                          -0.075322
# CC_temperature skewness                          -0.091156
# CC charge time                                   -0.267931
# CC Q                                             -0.267894
# voltage slope                                     0.283315
# voltage entropy                                  -0.374362
# current mean                                      0.221130
# current std                                       0.017342
# current kurtosis                                 -0.319140
# current skewness                                 -0.180341
# CV_temperature mean                               0.174248
# CV_temperature std                               -0.354311
# CV_temperature kurtosis                           0.326496
# CV_temperature skewness                          -0.280460
# CV charge time                                    0.196330
# CV Q                                              0.214905
# current slope                                     0.171662
# current entropy                                  -0.091017
# Battery_impedance_real_mean                       0.113240
# Battery_impedance_real_max                        1.000000
# Battery_impedance_imag_mean                       0.277043
# Battery_impedance_imag_max                        0.371935
# Rectified_impedance_real_mean                     0.532111
# Rectified_impedance_real_max                      0.526230
# Rectified_impedance_imag_mean                    -0.392119
# Rectified_impedance_imag_max                      0.682039
# Re                                                0.566195
# Rct                                               0.508375
#
#                                 Battery_impedance_imag_mean  \
# discharge voltage mean                             0.394167
# discharge voltage std                             -0.089841
# discharge voltage kurtosis                         0.272118
# discharge voltage skewness                        -0.218794
# discharge voltage cov                             -0.158859
# discharge_temperature mean                        -0.257984
# discharge_temperature std                         -0.366347
# discharge_temperature kurtosis                     0.341230
# discharge_temperature skewness                    -0.184349
# discharge_temperature cov                         -0.367338
# discharge time                                     0.437991
# discharge Q                                       -0.384261
# discharge voltage slope                           -0.256073
# discharge voltage entropy                         -0.740480
# capacity                                           0.389047
# voltage mean                                      -0.505759
# voltage std                                        0.196627
# voltage kurtosis                                   0.090799
# voltage skewness                                   0.487918
# CC_temperature mean                               -0.320445
# CC_temperature std                                 0.413016
# CC_temperature kurtosis                            0.203927
# CC_temperature skewness                            0.267126
# CC charge time                                     0.346736
# CC Q                                               0.346810
# voltage slope                                     -0.288268
# voltage entropy                                   -0.523904
# current mean                                       0.624970
# current std                                       -0.520753
# current kurtosis                                  -0.301702
# current skewness                                  -0.634920
# CV_temperature mean                               -0.287027
# CV_temperature std                                -0.434512
# CV_temperature kurtosis                           -0.118414
# CV_temperature skewness                            0.299358
# CV charge time                                    -0.475122
# CV Q                                              -0.442753
# current slope                                     -0.508704
# current entropy                                   -0.729557
# Battery_impedance_real_mean                       -0.556029
# Battery_impedance_real_max                         0.277043
# Battery_impedance_imag_mean                        1.000000
# Battery_impedance_imag_max                         0.978186
# Rectified_impedance_real_mean                     -0.392883
# Rectified_impedance_real_max                      -0.378867
# Rectified_impedance_imag_mean                      0.282396
# Rectified_impedance_imag_max                      -0.199511
# Re                                                -0.392359
# Rct                                               -0.380437
#
#                                 Battery_impedance_imag_max  \
# discharge voltage mean                            0.313014
# discharge voltage std                            -0.050584
# discharge voltage kurtosis                        0.271940
# discharge voltage skewness                       -0.218884
# discharge voltage cov                            -0.106644
# discharge_temperature mean                       -0.210415
# discharge_temperature std                        -0.330683
# discharge_temperature kurtosis                    0.280019
# discharge_temperature skewness                   -0.195592
# discharge_temperature cov                        -0.340518
# discharge time                                    0.440429
# discharge Q                                      -0.366334
# discharge voltage slope                          -0.239340
# discharge voltage entropy                        -0.720298
# capacity                                          0.368560
# voltage mean                                     -0.489696
# voltage std                                       0.189551
# voltage kurtosis                                  0.086208
# voltage skewness                                  0.472848
# CC_temperature mean                              -0.312636
# CC_temperature std                                0.413829
# CC_temperature kurtosis                           0.171858
# CC_temperature skewness                           0.243655
# CC charge time                                    0.334911
# CC Q                                              0.334983
# voltage slope                                    -0.279738
# voltage entropy                                  -0.506164
# current mean                                      0.596505
# current std                                      -0.498777
# current kurtosis                                 -0.288546
# current skewness                                 -0.611748
# CV_temperature mean                              -0.271428
# CV_temperature std                               -0.419009
# CV_temperature kurtosis                          -0.115569
# CV_temperature skewness                           0.289306
# CV charge time                                   -0.457739
# CV Q                                             -0.427463
# current slope                                    -0.490059
# current entropy                                  -0.704776
# Battery_impedance_real_mean                      -0.582886
# Battery_impedance_real_max                        0.371935
# Battery_impedance_imag_mean                       0.978186
# Battery_impedance_imag_max                        1.000000
# Rectified_impedance_real_mean                    -0.325116
# Rectified_impedance_real_max                     -0.313268
# Rectified_impedance_imag_mean                     0.247350
# Rectified_impedance_imag_max                     -0.068929
# Re                                               -0.311665
# Rct                                              -0.318303
#
#                                 Rectified_impedance_real_mean  \
# discharge voltage mean                              -0.896839
# discharge voltage std                                0.046465
# discharge voltage kurtosis                          -0.595894
# discharge voltage skewness                           0.562169
# discharge voltage cov                                0.214706
# discharge_temperature mean                           0.456457
# discharge_temperature std                            0.605559
# discharge_temperature kurtosis                      -0.843812
# discharge_temperature skewness                      -0.293083
# discharge_temperature cov                            0.586728
# discharge time                                      -0.604614
# discharge Q                                          0.729453
# discharge voltage slope                              0.622954
# discharge voltage entropy                            0.089422
# capacity                                            -0.733000
# voltage mean                                         0.535909
# voltage std                                         -0.485965
# voltage kurtosis                                     0.402993
# voltage skewness                                    -0.541067
# CC_temperature mean                                  0.373763
# CC_temperature std                                  -0.495606
# CC_temperature kurtosis                              0.031918
# CC_temperature skewness                             -0.121530
# CC charge time                                      -0.572584
# CC Q                                                -0.572642
# voltage slope                                        0.559390
# voltage entropy                                     -0.197716
# current mean                                        -0.064608
# current std                                          0.385115
# current kurtosis                                    -0.287151
# current skewness                                     0.126953
# CV_temperature mean                                  0.395826
# CV_temperature std                                  -0.224075
# CV_temperature kurtosis                              0.512735
# CV_temperature skewness                             -0.560748
# CV charge time                                       0.547290
# CV Q                                                 0.554371
# current slope                                        0.533055
# current entropy                                      0.311082
# Battery_impedance_real_mean                          0.508083
# Battery_impedance_real_max                           0.532111
# Battery_impedance_imag_mean                         -0.392883
# Battery_impedance_imag_max                          -0.325116
# Rectified_impedance_real_mean                        1.000000
# Rectified_impedance_real_max                         0.993348
# Rectified_impedance_imag_mean                       -0.890144
# Rectified_impedance_imag_max                         0.674775
# Re                                                   0.986614
# Rct                                                  0.991736
#
#                                 Rectified_impedance_real_max  \
# discharge voltage mean                             -0.908144
# discharge voltage std                               0.058153
# discharge voltage kurtosis                         -0.589658
# discharge voltage skewness                          0.555862
# discharge voltage cov                               0.227888
# discharge_temperature mean                          0.476166
# discharge_temperature std                           0.634476
# discharge_temperature kurtosis                     -0.828044
# discharge_temperature skewness                     -0.313282
# discharge_temperature cov                           0.615476
# discharge time                                     -0.627618
# discharge Q                                         0.755548
# discharge voltage slope                             0.626899
# discharge voltage entropy                           0.080921
# capacity                                           -0.759375
# voltage mean                                        0.562855
# voltage std                                        -0.526324
# voltage kurtosis                                    0.449138
# voltage skewness                                   -0.569142
# CC_temperature mean                                 0.374511
# CC_temperature std                                 -0.514701
# CC_temperature kurtosis                             0.035841
# CC_temperature skewness                            -0.133704
# CC charge time                                     -0.604588
# CC Q                                               -0.604640
# voltage slope                                       0.596854
# voltage entropy                                    -0.231238
# current mean                                       -0.043672
# current std                                         0.391341
# current kurtosis                                   -0.326423
# current skewness                                    0.110842
# CV_temperature mean                                 0.397016
# CV_temperature std                                 -0.262041
# CV_temperature kurtosis                             0.552694
# CV_temperature skewness                            -0.592320
# CV charge time                                      0.571191
# CV Q                                                0.580690
# current slope                                       0.554154
# current entropy                                     0.310567
# Battery_impedance_real_mean                         0.522254
# Battery_impedance_real_max                          0.526230
# Battery_impedance_imag_mean                        -0.378867
# Battery_impedance_imag_max                         -0.313268
# Rectified_impedance_real_mean                       0.993348
# Rectified_impedance_real_max                        1.000000
# Rectified_impedance_imag_mean                      -0.913084
# Rectified_impedance_imag_max                        0.654580
# Re                                                  0.971403
# Rct                                                 0.995246
#
#                                 Rectified_impedance_imag_mean  \
# discharge voltage mean                               0.820968
# discharge voltage std                               -0.061461
# discharge voltage kurtosis                           0.490285
# discharge voltage skewness                          -0.464665
# discharge voltage cov                               -0.214692
# discharge_temperature mean                          -0.349165
# discharge_temperature std                           -0.558850
# discharge_temperature kurtosis                       0.677197
# discharge_temperature skewness                       0.389991
# discharge_temperature cov                           -0.566562
# discharge time                                       0.571994
# discharge Q                                         -0.700375
# discharge voltage slope                             -0.535996
# discharge voltage entropy                            0.000600
# capacity                                             0.704768
# voltage mean                                        -0.476857
# voltage std                                          0.502624
# voltage kurtosis                                    -0.481684
# voltage skewness                                     0.486416
# CC_temperature mean                                 -0.274489
# CC_temperature std                                   0.475323
# CC_temperature kurtosis                             -0.148485
# CC_temperature skewness                              0.051762
# CC charge time                                       0.533143
# CC Q                                                 0.533212
# voltage slope                                       -0.544985
# voltage entropy                                      0.310063
# current mean                                        -0.086255
# current std                                         -0.318070
# current kurtosis                                     0.407487
# current skewness                                     0.014974
# CV_temperature mean                                 -0.273676
# CV_temperature std                                   0.346202
# CV_temperature kurtosis                             -0.531404
# CV_temperature skewness                              0.535726
# CV charge time                                      -0.475939
# CV Q                                                -0.494525
# current slope                                       -0.452910
# current entropy                                     -0.186807
# Battery_impedance_real_mean                         -0.422447
# Battery_impedance_real_max                          -0.392119
# Battery_impedance_imag_mean                          0.282396
# Battery_impedance_imag_max                           0.247350
# Rectified_impedance_real_mean                       -0.890144
# Rectified_impedance_real_max                        -0.913084
# Rectified_impedance_imag_mean                        1.000000
# Rectified_impedance_imag_max                        -0.487119
# Re                                                  -0.836430
# Rct                                                 -0.926117
#
#                                 Rectified_impedance_imag_max        Re  \
# discharge voltage mean                             -0.627387 -0.875678
# discharge voltage std                               0.017982  0.059444
# discharge voltage kurtosis                         -0.248125 -0.559583
# discharge voltage skewness                          0.260602  0.525705
# discharge voltage cov                               0.136804  0.223007
# discharge_temperature mean                          0.308045  0.442607
# discharge_temperature std                           0.268981  0.556233
# discharge_temperature kurtosis                     -0.550745 -0.832078
# discharge_temperature skewness                     -0.297552 -0.267521
# discharge_temperature cov                           0.216654  0.530014
# discharge time                                     -0.143970 -0.547897
# discharge Q                                         0.296316  0.671587
# discharge voltage slope                             0.241443  0.580120
# discharge voltage entropy                           0.049942  0.090022
# capacity                                           -0.304611 -0.676536
# voltage mean                                        0.186255  0.489617
# voltage std                                        -0.166178 -0.427661
# voltage kurtosis                                    0.123168  0.342754
# voltage skewness                                   -0.186953 -0.493431
# CC_temperature mean                                 0.106730  0.368546
# CC_temperature std                                 -0.098541 -0.447009
# CC_temperature kurtosis                            -0.125990 -0.000380
# CC_temperature skewness                            -0.139598 -0.125983
# CC charge time                                     -0.188031 -0.518446
# CC Q                                               -0.188014 -0.518494
# voltage slope                                       0.184116  0.502482
# voltage entropy                                    -0.027755 -0.151609
# current mean                                       -0.051634 -0.087722
# current std                                         0.092454  0.343715
# current kurtosis                                   -0.047988 -0.226769
# current skewness                                    0.070124  0.140463
# CV_temperature mean                                 0.143648  0.390476
# CV_temperature std                                 -0.043651 -0.173444
# CV_temperature kurtosis                             0.160440  0.455535
# CV_temperature skewness                            -0.175578 -0.501875
# CV charge time                                      0.186480  0.500994
# CV Q                                                0.186910  0.505137
# current slope                                       0.184045  0.489927
# current entropy                                     0.134020  0.304110
# Battery_impedance_real_mean                         0.040504  0.442626
# Battery_impedance_real_max                          0.682039  0.566195
# Battery_impedance_imag_mean                        -0.199511 -0.392359
# Battery_impedance_imag_max                         -0.068929 -0.311665
# Rectified_impedance_real_mean                       0.674775  0.986614
# Rectified_impedance_real_max                        0.654580  0.971403
# Rectified_impedance_imag_mean                      -0.487119 -0.836430
# Rectified_impedance_imag_max                        1.000000  0.749988
# Re                                                  0.749988  1.000000
# Rct                                                 0.639927  0.965620
#
#                                      Rct
# discharge voltage mean         -0.900418
# discharge voltage std           0.067106
# discharge voltage kurtosis     -0.576679
# discharge voltage skewness      0.540012
# discharge voltage cov           0.234907
# discharge_temperature mean      0.457403
# discharge_temperature std       0.622936
# discharge_temperature kurtosis -0.815614
# discharge_temperature skewness -0.306823
# discharge_temperature cov       0.607872
# discharge time                 -0.620168
# discharge Q                     0.743600
# discharge voltage slope         0.613307
# discharge voltage entropy       0.083806
# capacity                       -0.747976
# voltage mean                    0.551481
# voltage std                    -0.521252
# voltage kurtosis                0.449094
# voltage skewness               -0.557887
# CC_temperature mean             0.370794
# CC_temperature std             -0.517372
# CC_temperature kurtosis         0.064137
# CC_temperature skewness        -0.111265
# CC charge time                 -0.596035
# CC Q                           -0.596100
# voltage slope                   0.588340
# voltage entropy                -0.241350
# current mean                   -0.027810
# current std                     0.385415
# current kurtosis               -0.336755
# current skewness                0.095885
# CV_temperature mean             0.389421
# CV_temperature std             -0.272244
# CV_temperature kurtosis         0.549579
# CV_temperature skewness        -0.586696
# CV charge time                  0.559934
# CV Q                            0.570452
# current slope                   0.542367
# current entropy                 0.294650
# Battery_impedance_real_mean     0.512135
# Battery_impedance_real_max      0.508375
# Battery_impedance_imag_mean    -0.380437
# Battery_impedance_imag_max     -0.318303
# Rectified_impedance_real_mean   0.991736
# Rectified_impedance_real_max    0.995246
# Rectified_impedance_imag_mean  -0.926117
# Rectified_impedance_imag_max    0.639927
# Re                              0.965620
# Rct                             1.000000
#
# [49 rows x 49 columns]
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/2044535960.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=batch1_pearson_corr.values, y=batch1_pearson_corr.index, palette="viridis")

# %%
# Battery batch information
Batch1 = ['B0005', 'B0006', 'B0007', 'B0018']
Batch2 = ['B0025', 'B0026', 'B0027', 'B0028']
Batch3 = ['B0029', 'B0030', 'B0031', 'B0032']
Batch4 = ['B0033', 'B0034', 'B0036']
Batch5 = ['B0038', 'B0039', 'B0040']
Batch6 = ['B0041', 'B0042', 'B0043', 'B0044']
Batch7 = ['B0045', 'B0046', 'B0047', 'B0048']
Batch9 = ['B0053', 'B0054', 'B0055', 'B0056']

Batch = {'Batch1': Batch1, 'Batch2': Batch2, 'Batch3': Batch3, 'Batch4': Batch4, 'Batch5': Batch5, 'Batch6': Batch6, 'Batch7': Batch7,  'Batch9': Batch9}

# Set the output folder path
output_folder = '/Users/jonathanzha/Desktop/Battery-dataset-preprocessing-code-library/NASA/MergedOutput'

all_data = []

# Load features from all batches
for batch in Batch:
    batch_folder = os.path.join(output_folder, batch)
    if os.path.exists(batch_folder):
        files = [f for f in os.listdir(batch_folder) if f.endswith('_Merged_discharge+charge+impedance.csv')]
        for file in files:
            file_path = os.path.join(batch_folder, file)
            data = pd.read_csv(file_path)
            all_data.append(data)

# Combine all data into one DataFrame
combined_data = pd.concat(all_data, ignore_index=True)

# Compute the Pearson correlation matrix
correlation_matrix = combined_data.corr()

# Display the correlation matrix
print("Pearson Correlation Matrix:")
print(correlation_matrix)

# Plotting the Pearson correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Pearson Correlation Matrix')
plt.show()

# Plotting the Pearson correlation coefficients for 'capacity'
if 'capacity' in combined_data.columns:
    pearson_corr = correlation_matrix['capacity'].drop('capacity')

    plt.figure(figsize=(10, 8))
    sns.barplot(x=pearson_corr.values, y=pearson_corr.index, palette="viridis")
    plt.title('Pearson Correlation with Capacity')
    plt.xlabel('Pearson Correlation Coefficient')
    plt.ylabel('Features')
    plt.grid(True)  # Add grid lines for better readability
    plt.tight_layout()  # Adjust the layout to make room for the labels
    plt.show()
else:
    print("Column 'capacity' not found in the data.")
# Out:
# Pearson Correlation Matrix:
#                                 discharge voltage mean  discharge voltage std  \
# discharge voltage mean                        1.000000              -0.356774
# discharge voltage std                        -0.356774               1.000000
# discharge voltage kurtosis                    0.558644              -0.166579
# discharge voltage skewness                   -0.761159              -0.070333
# discharge voltage cov                        -0.534632               0.978132
# discharge_temperature mean                    0.028067              -0.331492
# discharge_temperature std                    -0.462842               0.274061
# discharge_temperature kurtosis                0.483717              -0.111865
# discharge_temperature skewness               -0.031853               0.494112
# discharge_temperature cov                    -0.633661               0.707984
# discharge time                                0.053874              -0.211753
# discharge Q                                   0.187883               0.517033
# discharge voltage slope                       0.222154              -0.283046
# discharge voltage entropy                     0.041122              -0.499281
# capacity                                      0.041050              -0.608636
# voltage mean                                 -0.007884              -0.066960
# voltage std                                  -0.021540               0.139060
# voltage kurtosis                              0.047906              -0.178413
# voltage skewness                              0.006637               0.072624
# CC_temperature mean                          -0.001330              -0.019204
# CC_temperature std                            0.015057               0.035223
# CC_temperature kurtosis                      -0.010219               0.006483
# CC_temperature skewness                      -0.010219               0.020340
# CC charge time                               -0.015165               0.123881
# CC Q                                         -0.015130               0.123844
# voltage slope                                 0.017944              -0.137376
# voltage entropy                              -0.042874               0.105152
# current mean                                  0.028577              -0.060658
# current std                                  -0.045478              -0.017982
# current kurtosis                             -0.023401               0.120398
# current skewness                             -0.028158               0.060508
# CV_temperature mean                           0.014062              -0.051434
# CV_temperature std                           -0.042576               0.123602
# CV_temperature kurtosis                       0.043098              -0.179653
# CV_temperature skewness                      -0.009298               0.127688
# CV charge time                               -0.001304              -0.079342
# CV Q                                          0.001339              -0.091611
# current slope                                -0.004147              -0.066756
# current entropy                              -0.026978               0.021961
# Battery_impedance_real_mean                  -0.205497               0.459753
# Battery_impedance_real_max                   -0.225155               0.526782
# Battery_impedance_imag_mean                  -0.010344               0.346983
# Battery_impedance_imag_max                    0.004660               0.326925
# Rectified_impedance_real_mean                -0.237507               0.443219
# Rectified_impedance_real_max                 -0.169550               0.476509
# Rectified_impedance_imag_mean                 0.073826              -0.366706
# Rectified_impedance_imag_max                 -0.144288               0.018223
# Re                                           -0.215208               0.305092
# Rct                                          -0.130123               0.471448
#
#                                 discharge voltage kurtosis  \
# discharge voltage mean                            0.558644
# discharge voltage std                            -0.166579
# discharge voltage kurtosis                        1.000000
# discharge voltage skewness                       -0.687864
# discharge voltage cov                            -0.243152
# discharge_temperature mean                       -0.041925
# discharge_temperature std                        -0.226894
# discharge_temperature kurtosis                    0.533422
# discharge_temperature skewness                   -0.003634
# discharge_temperature cov                        -0.245570
# discharge time                                   -0.262631
# discharge Q                                       0.343626
# discharge voltage slope                           0.003915
# discharge voltage entropy                        -0.289363
# capacity                                         -0.313996
# voltage mean                                     -0.145807
# voltage std                                       0.101811
# voltage kurtosis                                 -0.010553
# voltage skewness                                  0.147863
# CC_temperature mean                              -0.085181
# CC_temperature std                                0.121583
# CC_temperature kurtosis                          -0.002167
# CC_temperature skewness                           0.002734
# CC charge time                                    0.154754
# CC Q                                              0.154829
# voltage slope                                    -0.137818
# voltage entropy                                  -0.040327
# current mean                                      0.073952
# current std                                      -0.152427
# current kurtosis                                  0.019702
# current skewness                                 -0.088863
# CV_temperature mean                              -0.106758
# CV_temperature std                               -0.030192
# CV_temperature kurtosis                          -0.087169
# CV_temperature skewness                           0.164031
# CV charge time                                   -0.157571
# CV Q                                             -0.158806
# current slope                                    -0.157353
# current entropy                                  -0.107779
# Battery_impedance_real_mean                      -0.233734
# Battery_impedance_real_max                       -0.210056
# Battery_impedance_imag_mean                       0.105131
# Battery_impedance_imag_max                        0.084221
# Rectified_impedance_real_mean                    -0.214355
# Rectified_impedance_real_max                     -0.084132
# Rectified_impedance_imag_mean                    -0.056301
# Rectified_impedance_imag_max                     -0.214590
# Re                                               -0.275724
# Rct                                              -0.024661
#
#                                 discharge voltage skewness  \
# discharge voltage mean                           -0.761159
# discharge voltage std                            -0.070333
# discharge voltage kurtosis                       -0.687864
# discharge voltage skewness                        1.000000
# discharge voltage cov                             0.092950
# discharge_temperature mean                        0.183168
# discharge_temperature std                         0.328668
# discharge_temperature kurtosis                   -0.534309
# discharge_temperature skewness                   -0.252695
# discharge_temperature cov                         0.193227
# discharge time                                    0.139230
# discharge Q                                      -0.427662
# discharge voltage slope                          -0.163719
# discharge voltage entropy                         0.164426
# capacity                                          0.278789
# voltage mean                                      0.068615
# voltage std                                      -0.056589
# voltage kurtosis                                  0.035818
# voltage skewness                                 -0.070941
# CC_temperature mean                               0.069045
# CC_temperature std                               -0.093861
# CC_temperature kurtosis                           0.032349
# CC_temperature skewness                           0.028932
# CC charge time                                   -0.090174
# CC Q                                             -0.090219
# voltage slope                                     0.083629
# voltage entropy                                  -0.015641
# current mean                                     -0.008227
# current std                                       0.082122
# current kurtosis                                 -0.049123
# current skewness                                  0.018343
# CV_temperature mean                               0.067794
# CV_temperature std                               -0.017105
# CV_temperature kurtosis                           0.070351
# CV_temperature skewness                          -0.100098
# CV charge time                                    0.079638
# CV Q                                              0.082660
# current slope                                     0.076759
# current entropy                                   0.031720
# Battery_impedance_real_mean                       0.021202
# Battery_impedance_real_max                       -0.028992
# Battery_impedance_imag_mean                      -0.250855
# Battery_impedance_imag_max                       -0.249037
# Rectified_impedance_real_mean                     0.033527
# Rectified_impedance_real_max                     -0.090249
# Rectified_impedance_imag_mean                     0.170098
# Rectified_impedance_imag_max                      0.188450
# Re                                                0.119968
# Rct                                              -0.138393
#
#                                 discharge voltage cov  \
# discharge voltage mean                      -0.534632
# discharge voltage std                        0.978132
# discharge voltage kurtosis                  -0.243152
# discharge voltage skewness                   0.092950
# discharge voltage cov                        1.000000
# discharge_temperature mean                  -0.314635
# discharge_temperature std                    0.340890
# discharge_temperature kurtosis              -0.182214
# discharge_temperature skewness               0.446672
# discharge_temperature cov                    0.781870
# discharge time                              -0.213533
# discharge Q                                  0.437315
# discharge voltage slope                     -0.321233
# discharge voltage entropy                   -0.471792
# capacity                                    -0.576185
# voltage mean                                -0.062839
# voltage std                                  0.136115
# voltage kurtosis                            -0.179571
# voltage skewness                             0.068638
# CC_temperature mean                         -0.024396
# CC_temperature std                           0.039175
# CC_temperature kurtosis                      0.001069
# CC_temperature skewness                      0.014178
# CC charge time                               0.123943
# CC Q                                         0.123907
# voltage slope                               -0.136458
# voltage entropy                              0.112033
# current mean                                -0.066224
# current std                                 -0.010167
# current kurtosis                             0.123979
# current skewness                             0.064913
# CV_temperature mean                         -0.055306
# CV_temperature std                           0.129789
# CV_temperature kurtosis                     -0.181343
# CV_temperature skewness                      0.127216
# CV charge time                              -0.076818
# CV Q                                        -0.089327
# current slope                               -0.064106
# current entropy                              0.027688
# Battery_impedance_real_mean                  0.453895
# Battery_impedance_real_max                   0.516659
# Battery_impedance_imag_mean                  0.318539
# Battery_impedance_imag_max                   0.292388
# Rectified_impedance_real_mean                0.448905
# Rectified_impedance_real_max                 0.467261
# Rectified_impedance_imag_mean               -0.352255
# Rectified_impedance_imag_max                 0.035036
# Re                                           0.316549
# Rct                                          0.455178
#
#                                 discharge_temperature mean  \
# discharge voltage mean                            0.028067
# discharge voltage std                            -0.331492
# discharge voltage kurtosis                       -0.041925
# discharge voltage skewness                        0.183168
# discharge voltage cov                            -0.314635
# discharge_temperature mean                        1.000000
# discharge_temperature std                         0.494193
# discharge_temperature kurtosis                   -0.327300
# discharge_temperature skewness                   -0.277397
# discharge_temperature cov                        -0.523184
# discharge time                                   -0.075820
# discharge Q                                      -0.594539
# discharge voltage slope                           0.034495
# discharge voltage entropy                         0.140045
# capacity                                          0.582504
# voltage mean                                      0.115648
# voltage std                                      -0.183320
# voltage kurtosis                                  0.224380
# voltage skewness                                 -0.123736
# CC_temperature mean                               0.125549
# CC_temperature std                               -0.138044
# CC_temperature kurtosis                           0.031186
# CC_temperature skewness                           0.018545
# CC charge time                                   -0.221101
# CC Q                                             -0.221155
# voltage slope                                     0.222757
# voltage entropy                                  -0.163017
# current mean                                      0.089729
# current std                                       0.059896
# current kurtosis                                 -0.180662
# current skewness                                 -0.076149
# CV_temperature mean                               0.155714
# CV_temperature std                               -0.198289
# CV_temperature kurtosis                           0.268682
# CV_temperature skewness                          -0.225583
# CV charge time                                    0.149578
# CV Q                                              0.168580
# current slope                                     0.131930
# current entropy                                  -0.022755
# Battery_impedance_real_mean                      -0.214034
# Battery_impedance_real_max                       -0.266121
# Battery_impedance_imag_mean                      -0.612669
# Battery_impedance_imag_max                       -0.471650
# Rectified_impedance_real_mean                    -0.354060
# Rectified_impedance_real_max                     -0.695437
# Rectified_impedance_imag_mean                     0.863513
# Rectified_impedance_imag_max                      0.413363
# Re                                               -0.001455
# Rct                                              -0.761200
#
#                                 discharge_temperature std  \
# discharge voltage mean                          -0.462842
# discharge voltage std                            0.274061
# discharge voltage kurtosis                      -0.226894
# discharge voltage skewness                       0.328668
# discharge voltage cov                            0.340890
# discharge_temperature mean                       0.494193
# discharge_temperature std                        1.000000
# discharge_temperature kurtosis                  -0.452667
# discharge_temperature skewness                   0.072054
# discharge_temperature cov                        0.381429
# discharge time                                  -0.282993
# discharge Q                                     -0.207633
# discharge voltage slope                          0.002696
# discharge voltage entropy                       -0.133431
# capacity                                         0.042446
# voltage mean                                     0.270428
# voltage std                                     -0.205064
# voltage kurtosis                                 0.034572
# voltage skewness                                -0.272115
# CC_temperature mean                              0.158113
# CC_temperature std                              -0.140891
# CC_temperature kurtosis                         -0.092044
# CC_temperature skewness                         -0.098012
# CC charge time                                  -0.288499
# CC Q                                            -0.288549
# voltage slope                                    0.261865
# voltage entropy                                  0.084516
# current mean                                    -0.158435
# current std                                      0.217055
# current kurtosis                                 0.042650
# current skewness                                 0.178962
# CV_temperature mean                              0.245124
# CV_temperature std                               0.071176
# CV_temperature kurtosis                          0.192067
# CV_temperature skewness                         -0.278320
# CV charge time                                   0.291705
# CV Q                                             0.292883
# current slope                                    0.287222
# current entropy                                  0.207813
# Battery_impedance_real_mean                      0.174361
# Battery_impedance_real_max                       0.149139
# Battery_impedance_imag_mean                     -0.336401
# Battery_impedance_imag_max                      -0.260453
# Rectified_impedance_real_mean                    0.050396
# Rectified_impedance_real_max                    -0.218687
# Rectified_impedance_imag_mean                    0.436443
# Rectified_impedance_imag_max                     0.331300
# Re                                               0.218033
# Rct                                             -0.290165
#
#                                 discharge_temperature kurtosis  \
# discharge voltage mean                                0.483717
# discharge voltage std                                -0.111865
# discharge voltage kurtosis                            0.533422
# discharge voltage skewness                           -0.534309
# discharge voltage cov                                -0.182214
# discharge_temperature mean                           -0.327300
# discharge_temperature std                            -0.452667
# discharge_temperature kurtosis                        1.000000
# discharge_temperature skewness                       -0.186187
# discharge_temperature cov                            -0.184052
# discharge time                                       -0.020455
# discharge Q                                           0.374566
# discharge voltage slope                               0.050455
# discharge voltage entropy                            -0.100894
# capacity                                             -0.299833
# voltage mean                                         -0.172691
# voltage std                                           0.171291
# voltage kurtosis                                     -0.082121
# voltage skewness                                      0.175237
# CC_temperature mean                                  -0.060099
# CC_temperature std                                    0.056622
# CC_temperature kurtosis                               0.079037
# CC_temperature skewness                               0.082422
# CC charge time                                        0.191568
# CC Q                                                  0.191574
# voltage slope                                        -0.184246
# voltage entropy                                      -0.021507
# current mean                                          0.075925
# current std                                          -0.136786
# current kurtosis                                      0.027608
# current skewness                                     -0.079159
# CV_temperature mean                                  -0.125914
# CV_temperature std                                    0.005671
# CV_temperature kurtosis                              -0.156890
# CV_temperature skewness                               0.186107
# CV charge time                                       -0.188242
# CV Q                                                 -0.191806
# current slope                                        -0.185284
# current entropy                                      -0.112091
# Battery_impedance_real_mean                           0.038968
# Battery_impedance_real_max                            0.035634
# Battery_impedance_imag_mean                           0.276631
# Battery_impedance_imag_max                            0.223303
# Rectified_impedance_real_mean                         0.116540
# Rectified_impedance_real_max                          0.274323
# Rectified_impedance_imag_mean                        -0.357995
# Rectified_impedance_imag_max                         -0.218690
# Re                                                   -0.010243
# Rct                                                   0.310727
#
#                                 discharge_temperature skewness  \
# discharge voltage mean                               -0.031853
# discharge voltage std                                 0.494112
# discharge voltage kurtosis                           -0.003634
# discharge voltage skewness                           -0.252695
# discharge voltage cov                                 0.446672
# discharge_temperature mean                           -0.277397
# discharge_temperature std                             0.072054
# discharge_temperature kurtosis                       -0.186187
# discharge_temperature skewness                        1.000000
# discharge_temperature cov                             0.385006
# discharge time                                        0.081707
# discharge Q                                           0.312457
# discharge voltage slope                              -0.008549
# discharge voltage entropy                            -0.076907
# capacity                                             -0.328693
# voltage mean                                         -0.001489
# voltage std                                           0.055028
# voltage kurtosis                                     -0.142898
# voltage skewness                                      0.007106
# CC_temperature mean                                  -0.079042
# CC_temperature std                                    0.104533
# CC_temperature kurtosis                              -0.102968
# CC_temperature skewness                              -0.083163
# CC charge time                                        0.070829
# CC Q                                                  0.070876
# voltage slope                                        -0.080890
# voltage entropy                                       0.141627
# current mean                                         -0.102281
# current std                                           0.012975
# current kurtosis                                      0.131734
# current skewness                                      0.097002
# CV_temperature mean                                  -0.051872
# CV_temperature std                                    0.139624
# CV_temperature kurtosis                              -0.130152
# CV_temperature skewness                               0.078004
# CV charge time                                       -0.016819
# CV Q                                                 -0.027873
# current slope                                        -0.004535
# current entropy                                       0.078115
# Battery_impedance_real_mean                           0.258403
# Battery_impedance_real_max                            0.336984
# Battery_impedance_imag_mean                           0.347591
# Battery_impedance_imag_max                            0.333448
# Rectified_impedance_real_mean                         0.240324
# Rectified_impedance_real_max                          0.341102
# Rectified_impedance_imag_mean                        -0.323007
# Rectified_impedance_imag_max                         -0.070429
# Re                                                    0.128958
# Rct                                                   0.366718
#
#                                 discharge_temperature cov  ...  \
# discharge voltage mean                          -0.633661  ...
# discharge voltage std                            0.707984  ...
# discharge voltage kurtosis                      -0.245570  ...
# discharge voltage skewness                       0.193227  ...
# discharge voltage cov                            0.781870  ...
# discharge_temperature mean                      -0.523184  ...
# discharge_temperature std                        0.381429  ...
# discharge_temperature kurtosis                  -0.184052  ...
# discharge_temperature skewness                   0.385006  ...
# discharge_temperature cov                        1.000000  ...
# discharge time                                  -0.180797  ...
# discharge Q                                      0.387633  ...
# discharge voltage slope                         -0.081702  ...
# discharge voltage entropy                       -0.275845  ...
# capacity                                        -0.569237  ...
# voltage mean                                     0.028363  ...
# voltage std                                      0.080115  ...
# voltage kurtosis                                -0.214429  ...
# voltage skewness                                -0.020854  ...
# CC_temperature mean                             -0.050969  ...
# CC_temperature std                               0.072550  ...
# CC_temperature kurtosis                         -0.097315  ...
# CC_temperature skewness                         -0.088778  ...
# CC charge time                                   0.070620  ...
# CC Q                                             0.070642  ...
# voltage slope                                   -0.086619  ...
# voltage entropy                                  0.216760  ...
# current mean                                    -0.178979  ...
# current std                                      0.055909  ...
# current kurtosis                                 0.215832  ...
# current skewness                                 0.173134  ...
# CV_temperature mean                             -0.035226  ...
# CV_temperature std                               0.238665  ...
# CV_temperature kurtosis                         -0.174072  ...
# CV_temperature skewness                          0.084085  ...
# CV charge time                                   0.005665  ...
# CV Q                                            -0.012634  ...
# current slope                                    0.021868  ...
# current entropy                                  0.138640  ...
# Battery_impedance_real_mean                      0.422610  ...
# Battery_impedance_real_max                       0.477189  ...
# Battery_impedance_imag_mean                      0.353293  ...
# Battery_impedance_imag_max                       0.292195  ...
# Rectified_impedance_real_mean                    0.454637  ...
# Rectified_impedance_real_max                     0.532549  ...
# Rectified_impedance_imag_mean                   -0.482533  ...
# Rectified_impedance_imag_max                    -0.062917  ...
# Re                                               0.248929  ...
# Rct                                              0.528599  ...
#
#                                 Battery_impedance_real_mean  \
# discharge voltage mean                            -0.205497
# discharge voltage std                              0.459753
# discharge voltage kurtosis                        -0.233734
# discharge voltage skewness                         0.021202
# discharge voltage cov                              0.453895
# discharge_temperature mean                        -0.214034
# discharge_temperature std                          0.174361
# discharge_temperature kurtosis                     0.038968
# discharge_temperature skewness                     0.258403
# discharge_temperature cov                          0.422610
# discharge time                                     0.049376
# discharge Q                                        0.321302
# discharge voltage slope                            0.064116
# discharge voltage entropy                         -0.083445
# capacity                                          -0.364675
# voltage mean                                      -0.031262
# voltage std                                        0.083750
# voltage kurtosis                                  -0.123581
# voltage skewness                                   0.034866
# CC_temperature mean                                0.020792
# CC_temperature std                                -0.022634
# CC_temperature kurtosis                            0.044576
# CC_temperature skewness                            0.051875
# CC charge time                                     0.059084
# CC Q                                               0.059049
# voltage slope                                     -0.074376
# voltage entropy                                    0.059013
# current mean                                      -0.030494
# current std                                        0.013087
# current kurtosis                                   0.064129
# current skewness                                   0.035648
# CV_temperature mean                               -0.014436
# CV_temperature std                                 0.066755
# CV_temperature kurtosis                           -0.104309
# CV_temperature skewness                            0.058235
# CV charge time                                    -0.036370
# CV Q                                              -0.042122
# current slope                                     -0.033756
# current entropy                                    0.016474
# Battery_impedance_real_mean                        1.000000
# Battery_impedance_real_max                         0.820536
# Battery_impedance_imag_mean                        0.106507
# Battery_impedance_imag_max                         0.145563
# Rectified_impedance_real_mean                      0.907810
# Rectified_impedance_real_max                       0.690183
# Rectified_impedance_imag_mean                     -0.263562
# Rectified_impedance_imag_max                       0.348394
# Re                                                 0.869722
# Rct                                                0.573462
#
#                                 Battery_impedance_real_max  \
# discharge voltage mean                           -0.225155
# discharge voltage std                             0.526782
# discharge voltage kurtosis                       -0.210056
# discharge voltage skewness                       -0.028992
# discharge voltage cov                             0.516659
# discharge_temperature mean                       -0.266121
# discharge_temperature std                         0.149139
# discharge_temperature kurtosis                    0.035634
# discharge_temperature skewness                    0.336984
# discharge_temperature cov                         0.477189
# discharge time                                    0.124318
# discharge Q                                       0.319541
# discharge voltage slope                           0.050709
# discharge voltage entropy                        -0.094022
# capacity                                         -0.367729
# voltage mean                                     -0.105426
# voltage std                                       0.132694
# voltage kurtosis                                 -0.120125
# voltage skewness                                  0.108312
# CC_temperature mean                              -0.034383
# CC_temperature std                                0.037599
# CC_temperature kurtosis                           0.048078
# CC_temperature skewness                           0.062847
# CC charge time                                    0.126741
# CC Q                                              0.126735
# voltage slope                                    -0.137035
# voltage entropy                                   0.017485
# current mean                                      0.019266
# current std                                      -0.047229
# current kurtosis                                  0.044606
# current skewness                                 -0.025855
# CV_temperature mean                              -0.070459
# CV_temperature std                                0.034079
# CV_temperature kurtosis                          -0.140997
# CV_temperature skewness                           0.119388
# CV charge time                                   -0.108056
# CV Q                                             -0.113606
# current slope                                    -0.103613
# current entropy                                  -0.049708
# Battery_impedance_real_mean                       0.820536
# Battery_impedance_real_max                        1.000000
# Battery_impedance_imag_mean                       0.420223
# Battery_impedance_imag_max                        0.472742
# Rectified_impedance_real_mean                     0.855279
# Rectified_impedance_real_max                      0.735381
# Rectified_impedance_imag_mean                    -0.382699
# Rectified_impedance_imag_max                      0.426698
# Re                                                0.794371
# Rct                                               0.649175
#
#                                 Battery_impedance_imag_mean  \
# discharge voltage mean                            -0.010344
# discharge voltage std                              0.346983
# discharge voltage kurtosis                         0.105131
# discharge voltage skewness                        -0.250855
# discharge voltage cov                              0.318539
# discharge_temperature mean                        -0.612669
# discharge_temperature std                         -0.336401
# discharge_temperature kurtosis                     0.276631
# discharge_temperature skewness                     0.347591
# discharge_temperature cov                          0.353293
# discharge time                                     0.213775
# discharge Q                                        0.412806
# discharge voltage slope                           -0.032471
# discharge voltage entropy                         -0.100088
# capacity                                          -0.415643
# voltage mean                                      -0.242533
# voltage std                                        0.242176
# voltage kurtosis                                  -0.145088
# voltage skewness                                   0.246576
# CC_temperature mean                               -0.137054
# CC_temperature std                                 0.149606
# CC_temperature kurtosis                            0.059077
# CC_temperature skewness                            0.075527
# CC charge time                                     0.293852
# CC Q                                               0.293901
# voltage slope                                     -0.283483
# voltage entropy                                    0.003931
# current mean                                       0.073229
# current std                                       -0.160495
# current kurtosis                                   0.064020
# current skewness                                  -0.097248
# CV_temperature mean                               -0.204966
# CV_temperature std                                 0.035712
# CV_temperature kurtosis                           -0.255097
# CV_temperature skewness                            0.288392
# CV charge time                                    -0.265284
# CV Q                                              -0.274444
# current slope                                     -0.255796
# current entropy                                   -0.140774
# Battery_impedance_real_mean                        0.106507
# Battery_impedance_real_max                         0.420223
# Battery_impedance_imag_mean                        1.000000
# Battery_impedance_imag_max                         0.945353
# Rectified_impedance_real_mean                      0.300270
# Rectified_impedance_real_max                       0.647472
# Rectified_impedance_imag_mean                     -0.789629
# Rectified_impedance_imag_max                      -0.296044
# Re                                                 0.048044
# Rct                                                0.720709
#
#                                 Battery_impedance_imag_max  \
# discharge voltage mean                            0.004660
# discharge voltage std                             0.326925
# discharge voltage kurtosis                        0.084221
# discharge voltage skewness                       -0.249037
# discharge voltage cov                             0.292388
# discharge_temperature mean                       -0.471650
# discharge_temperature std                        -0.260453
# discharge_temperature kurtosis                    0.223303
# discharge_temperature skewness                    0.333448
# discharge_temperature cov                         0.292195
# discharge time                                    0.234912
# discharge Q                                       0.346943
# discharge voltage slope                           0.001324
# discharge voltage entropy                        -0.043266
# capacity                                         -0.341612
# voltage mean                                     -0.209597
# voltage std                                       0.203595
# voltage kurtosis                                 -0.116800
# voltage skewness                                  0.212681
# CC_temperature mean                              -0.119330
# CC_temperature std                                0.135320
# CC_temperature kurtosis                           0.047548
# CC_temperature skewness                           0.062234
# CC charge time                                    0.248566
# CC Q                                              0.248615
# voltage slope                                    -0.240054
# voltage entropy                                  -0.006780
# current mean                                      0.070661
# current std                                      -0.138031
# current kurtosis                                  0.046892
# current skewness                                 -0.094621
# CV_temperature mean                              -0.171842
# CV_temperature std                                0.017097
# CV_temperature kurtosis                          -0.211216
# CV_temperature skewness                           0.244129
# CV charge time                                   -0.226556
# CV Q                                             -0.233716
# current slope                                    -0.219117
# current entropy                                  -0.127172
# Battery_impedance_real_mean                       0.145563
# Battery_impedance_real_max                        0.472742
# Battery_impedance_imag_mean                       0.945353
# Battery_impedance_imag_max                        1.000000
# Rectified_impedance_real_mean                     0.313813
# Rectified_impedance_real_max                      0.589199
# Rectified_impedance_imag_mean                    -0.664848
# Rectified_impedance_imag_max                     -0.137074
# Re                                                0.114644
# Rct                                               0.648934
#
#                                 Rectified_impedance_real_mean  \
# discharge voltage mean                              -0.237507
# discharge voltage std                                0.443219
# discharge voltage kurtosis                          -0.214355
# discharge voltage skewness                           0.033527
# discharge voltage cov                                0.448905
# discharge_temperature mean                          -0.354060
# discharge_temperature std                            0.050396
# discharge_temperature kurtosis                       0.116540
# discharge_temperature skewness                       0.240324
# discharge_temperature cov                            0.454637
# discharge time                                       0.073132
# discharge Q                                          0.364646
# discharge voltage slope                              0.022708
# discharge voltage entropy                           -0.124192
# capacity                                            -0.412536
# voltage mean                                        -0.126504
# voltage std                                          0.181036
# voltage kurtosis                                    -0.179782
# voltage skewness                                     0.131673
# CC_temperature mean                                 -0.026364
# CC_temperature std                                   0.026906
# CC_temperature kurtosis                              0.071408
# CC_temperature skewness                              0.088094
# CC charge time                                       0.170153
# CC Q                                                 0.170121
# voltage slope                                       -0.183545
# voltage entropy                                      0.055481
# current mean                                        -0.001623
# current std                                         -0.044570
# current kurtosis                                     0.080918
# current skewness                                    -0.002977
# CV_temperature mean                                 -0.088019
# CV_temperature std                                   0.077579
# CV_temperature kurtosis                             -0.201872
# CV_temperature skewness                              0.165147
# CV charge time                                      -0.136980
# CV Q                                                -0.146547
# current slope                                       -0.129955
# current entropy                                     -0.041086
# Battery_impedance_real_mean                          0.907810
# Battery_impedance_real_max                           0.855279
# Battery_impedance_imag_mean                          0.300270
# Battery_impedance_imag_max                           0.313813
# Rectified_impedance_real_mean                        1.000000
# Rectified_impedance_real_max                         0.851842
# Rectified_impedance_imag_mean                       -0.463769
# Rectified_impedance_imag_max                         0.344974
# Re                                                   0.921683
# Rct                                                  0.744179
#
#                                 Rectified_impedance_real_max  \
# discharge voltage mean                             -0.169550
# discharge voltage std                               0.476509
# discharge voltage kurtosis                         -0.084132
# discharge voltage skewness                         -0.090249
# discharge voltage cov                               0.467261
# discharge_temperature mean                         -0.695437
# discharge_temperature std                          -0.218687
# discharge_temperature kurtosis                      0.274323
# discharge_temperature skewness                      0.341102
# discharge_temperature cov                           0.532549
# discharge time                                      0.141634
# discharge Q                                         0.569364
# discharge voltage slope                            -0.009276
# discharge voltage entropy                          -0.160853
# capacity                                           -0.594296
# voltage mean                                       -0.191979
# voltage std                                         0.253794
# voltage kurtosis                                   -0.229157
# voltage skewness                                    0.198957
# CC_temperature mean                                -0.072034
# CC_temperature std                                  0.075412
# CC_temperature kurtosis                             0.077938
# CC_temperature skewness                             0.092141
# CC charge time                                      0.266728
# CC Q                                                0.266736
# voltage slope                                      -0.271756
# voltage entropy                                     0.084418
# current mean                                       -0.001600
# current std                                        -0.091645
# current kurtosis                                    0.126951
# current skewness                                   -0.010341
# CV_temperature mean                                -0.161075
# CV_temperature std                                  0.121488
# CV_temperature kurtosis                            -0.287863
# CV_temperature skewness                             0.265245
# CV charge time                                     -0.217966
# CV Q                                               -0.232315
# current slope                                      -0.206233
# current entropy                                    -0.064390
# Battery_impedance_real_mean                         0.690183
# Battery_impedance_real_max                          0.735381
# Battery_impedance_imag_mean                         0.647472
# Battery_impedance_imag_max                          0.589199
# Rectified_impedance_real_mean                       0.851842
# Rectified_impedance_real_max                        1.000000
# Rectified_impedance_imag_mean                      -0.847288
# Rectified_impedance_imag_max                        0.018697
# Re                                                  0.611351
# Rct                                                 0.976707
#
#                                 Rectified_impedance_imag_mean  \
# discharge voltage mean                               0.073826
# discharge voltage std                               -0.366706
# discharge voltage kurtosis                          -0.056301
# discharge voltage skewness                           0.170098
# discharge voltage cov                               -0.352255
# discharge_temperature mean                           0.863513
# discharge_temperature std                            0.436443
# discharge_temperature kurtosis                      -0.357995
# discharge_temperature skewness                      -0.323007
# discharge_temperature cov                           -0.482533
# discharge time                                      -0.147291
# discharge Q                                         -0.605726
# discharge voltage slope                              0.041704
# discharge voltage entropy                            0.156799
# capacity                                             0.606724
# voltage mean                                         0.200326
# voltage std                                         -0.255574
# voltage kurtosis                                     0.221609
# voltage skewness                                    -0.207476
# CC_temperature mean                                  0.109920
# CC_temperature std                                  -0.118343
# CC_temperature kurtosis                             -0.043875
# CC_temperature skewness                             -0.053274
# CC charge time                                      -0.290269
# CC Q                                                -0.290320
# voltage slope                                        0.285907
# voltage entropy                                     -0.102787
# current mean                                         0.014315
# current std                                          0.117299
# current kurtosis                                    -0.150699
# current skewness                                     0.002565
# CV_temperature mean                                  0.192787
# CV_temperature std                                  -0.144657
# CV_temperature kurtosis                              0.299305
# CV_temperature skewness                             -0.294591
# CV charge time                                       0.234583
# CV Q                                                 0.250800
# current slope                                        0.219568
# current entropy                                      0.059856
# Battery_impedance_real_mean                         -0.263562
# Battery_impedance_real_max                          -0.382699
# Battery_impedance_imag_mean                         -0.789629
# Battery_impedance_imag_max                          -0.664848
# Rectified_impedance_real_mean                       -0.463769
# Rectified_impedance_real_max                        -0.847288
# Rectified_impedance_imag_mean                        1.000000
# Rectified_impedance_imag_max                         0.386638
# Re                                                  -0.123936
# Rct                                                 -0.921904
#
#                                 Rectified_impedance_imag_max        Re  \
# discharge voltage mean                             -0.144288 -0.215208
# discharge voltage std                               0.018223  0.305092
# discharge voltage kurtosis                         -0.214590 -0.275724
# discharge voltage skewness                          0.188450  0.119968
# discharge voltage cov                               0.035036  0.316549
# discharge_temperature mean                          0.413363 -0.001455
# discharge_temperature std                           0.331300  0.218033
# discharge_temperature kurtosis                     -0.218690 -0.010243
# discharge_temperature skewness                     -0.070429  0.128958
# discharge_temperature cov                          -0.062917  0.248929
# discharge time                                      0.019227  0.070572
# discharge Q                                        -0.193711  0.117022
# discharge voltage slope                             0.059913  0.035607
# discharge voltage entropy                           0.086561 -0.046888
# capacity                                            0.178428 -0.163689
# voltage mean                                        0.104469 -0.061282
# voltage std                                        -0.118047  0.103613
# voltage kurtosis                                    0.082787 -0.113445
# voltage skewness                                   -0.107548  0.063871
# CC_temperature mean                                 0.070177  0.021939
# CC_temperature std                                 -0.078292 -0.026081
# CC_temperature kurtosis                            -0.003888  0.066072
# CC_temperature skewness                            -0.008181  0.080955
# CC charge time                                     -0.145545  0.070412
# CC Q                                               -0.145586  0.070360
# voltage slope                                       0.137889 -0.088586
# voltage entropy                                    -0.041472  0.017193
# current mean                                       -0.000942  0.005377
# current std                                         0.095438  0.000963
# current kurtosis                                   -0.068900  0.028294
# current skewness                                    0.005614 -0.004705
# CV_temperature mean                                 0.102245 -0.016093
# CV_temperature std                                 -0.059657  0.027187
# CV_temperature kurtosis                             0.133596 -0.103284
# CV_temperature skewness                            -0.151233  0.063325
# CV charge time                                      0.122626 -0.056958
# CV Q                                                0.129736 -0.061130
# current slope                                       0.113852 -0.054851
# current entropy                                     0.037776 -0.023313
# Battery_impedance_real_mean                         0.348394  0.869722
# Battery_impedance_real_max                          0.426698  0.794371
# Battery_impedance_imag_mean                        -0.296044  0.048044
# Battery_impedance_imag_max                         -0.137074  0.114644
# Rectified_impedance_real_mean                       0.344974  0.921683
# Rectified_impedance_real_max                        0.018697  0.611351
# Rectified_impedance_imag_mean                       0.386638 -0.123936
# Rectified_impedance_imag_max                        1.000000  0.541526
# Re                                                  0.541526  1.000000
# Rct                                                -0.122433  0.461853
#
#                                      Rct
# discharge voltage mean         -0.130123
# discharge voltage std           0.471448
# discharge voltage kurtosis     -0.024661
# discharge voltage skewness     -0.138393
# discharge voltage cov           0.455178
# discharge_temperature mean     -0.761200
# discharge_temperature std      -0.290165
# discharge_temperature kurtosis  0.310727
# discharge_temperature skewness  0.366718
# discharge_temperature cov       0.528599
# discharge time                  0.162467
# discharge Q                     0.607185
# discharge voltage slope        -0.018054
# discharge voltage entropy      -0.166496
# capacity                       -0.625113
# voltage mean                   -0.202733
# voltage std                     0.268073
# voltage kurtosis               -0.243363
# voltage skewness                0.210362
# CC_temperature mean            -0.092178
# CC_temperature std              0.102393
# CC_temperature kurtosis         0.056778
# CC_temperature skewness         0.070500
# CC charge time                  0.288045
# CC Q                            0.288079
# voltage slope                  -0.290880
# voltage entropy                 0.102455
# current mean                   -0.010727
# current std                    -0.113493
# current kurtosis                0.152546
# current skewness               -0.002716
# CV_temperature mean            -0.179480
# CV_temperature std              0.140949
# CV_temperature kurtosis        -0.307767
# CV_temperature skewness         0.291218
# CV charge time                 -0.232949
# CV Q                           -0.248848
# current slope                  -0.218879
# current entropy                -0.060116
# Battery_impedance_real_mean     0.573462
# Battery_impedance_real_max      0.649175
# Battery_impedance_imag_mean     0.720709
# Battery_impedance_imag_max      0.648934
# Rectified_impedance_real_mean   0.744179
# Rectified_impedance_real_max    0.976707
# Rectified_impedance_imag_mean  -0.921904
# Rectified_impedance_imag_max   -0.122433
# Re                              0.461853
# Rct                             1.000000
#
# [49 rows x 49 columns]
# /var/folders/rx/sf9l7p51187c9twd53tg_ss00000gn/T/ipykernel_56945/2940005974.py:54: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pearson_corr.values, y=pearson_corr.index, palette="viridis")
